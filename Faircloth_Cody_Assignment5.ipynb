# %% [markdown]
# # Module Five Assignment: Cartpole Problem
# Review the code in this notebook and in the score_logger.py file in the *scores* folder (directory). Once you have reviewed the code, return to this notebook and select **Cell** and then **Run All** from the menu bar to run this code. The code takes several minutes to run.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()
# Out:
# Using TensorFlow backend.

# %%
cartpole() #Stock params was quick but inconsistent
# Out:
# Run: 1, exploration: 0.8911090557802088, score: 43
# Scores: (min: 43, avg: 43, max: 43)
#
# Run: 2, exploration: 0.8348931673187264, score: 14
# Scores: (min: 14, avg: 28.5, max: 43)
#
# Run: 3, exploration: 0.736559652908221, score: 26
# Scores: (min: 14, avg: 27.666666666666668, max: 43)
#
# Run: 4, exploration: 0.653073201944699, score: 25
# Scores: (min: 14, avg: 27, max: 43)
#
# Run: 5, exploration: 0.6088145090359074, score: 15
# Scores: (min: 14, avg: 24.6, max: 43)
#
# Run: 6, exploration: 0.5535075230322891, score: 20
# Scores: (min: 14, avg: 23.833333333333332, max: 43)
#
# Run: 7, exploration: 0.5264466124450268, score: 11
# Scores: (min: 11, avg: 22, max: 43)
#
# Run: 8, exploration: 0.500708706245853, score: 11
# Scores: (min: 11, avg: 20.625, max: 43)
#
# Run: 9, exploration: 0.46211964903917074, score: 17
# Scores: (min: 11, avg: 20.22222222222222, max: 43)
#
# Run: 10, exploration: 0.4180382776616619, score: 21
# Scores: (min: 11, avg: 20.3, max: 43)
#
# Run: 11, exploration: 0.3995984329713264, score: 10
# Scores: (min: 10, avg: 19.363636363636363, max: 43)
#
# Run: 12, exploration: 0.37816180712868996, score: 12
# Scores: (min: 10, avg: 18.75, max: 43)
#
# Run: 13, exploration: 0.3578751580867638, score: 12
# Scores: (min: 10, avg: 18.23076923076923, max: 43)
#
# Run: 14, exploration: 0.3438081748424137, score: 9
# Scores: (min: 9, avg: 17.571428571428573, max: 43)
#
# Run: 15, exploration: 0.32864265128599696, score: 10
# Scores: (min: 9, avg: 17.066666666666666, max: 43)
#
# Run: 16, exploration: 0.3141460853680822, score: 10
# Scores: (min: 9, avg: 16.625, max: 43)
#
# Run: 17, exploration: 0.29285644267656924, score: 15
# Scores: (min: 9, avg: 16.529411764705884, max: 43)
#
# Run: 18, exploration: 0.27853872940185365, score: 11
# Scores: (min: 9, avg: 16.22222222222222, max: 43)
#
# Run: 19, exploration: 0.16873052768933355, score: 101
# Scores: (min: 9, avg: 20.68421052631579, max: 101)
#
# Run: 20, exploration: 0.10170090558064004, score: 102
# Scores: (min: 9, avg: 24.75, max: 102)
#
# Run: 21, exploration: 0.04652918187562211, score: 157
# Scores: (min: 9, avg: 31.047619047619047, max: 157)
#
# Run: 22, exploration: 0.020760672449809284, score: 162
# Scores: (min: 9, avg: 37, max: 162)
#
# Run: 23, exploration: 0.010447285872500434, score: 138
# Scores: (min: 9, avg: 41.391304347826086, max: 162)
#
# Run: 24, exploration: 0.01, score: 130
# Scores: (min: 9, avg: 45.083333333333336, max: 162)
#
# Run: 25, exploration: 0.01, score: 115
# Scores: (min: 9, avg: 47.88, max: 162)
#
# Run: 26, exploration: 0.01, score: 92
# Scores: (min: 9, avg: 49.57692307692308, max: 162)
#
# Run: 27, exploration: 0.01, score: 73
# Scores: (min: 9, avg: 50.44444444444444, max: 162)
#
# Run: 28, exploration: 0.01, score: 78
# Scores: (min: 9, avg: 51.42857142857143, max: 162)
#
# Run: 29, exploration: 0.01, score: 77
# Scores: (min: 9, avg: 52.310344827586206, max: 162)
#
# Run: 30, exploration: 0.01, score: 69
# Scores: (min: 9, avg: 52.86666666666667, max: 162)
#
# Run: 31, exploration: 0.01, score: 62
# Scores: (min: 9, avg: 53.16129032258065, max: 162)
#
# Run: 32, exploration: 0.01, score: 73
# Scores: (min: 9, avg: 53.78125, max: 162)
#
# Run: 33, exploration: 0.01, score: 87
# Scores: (min: 9, avg: 54.78787878787879, max: 162)
#
# Run: 34, exploration: 0.01, score: 142
# Scores: (min: 9, avg: 57.35294117647059, max: 162)
#
# Run: 35, exploration: 0.01, score: 80
# Scores: (min: 9, avg: 58, max: 162)
#
# Run: 36, exploration: 0.01, score: 156
# Scores: (min: 9, avg: 60.72222222222222, max: 162)
#
# Run: 37, exploration: 0.01, score: 160
# Scores: (min: 9, avg: 63.4054054054054, max: 162)
#
# Run: 38, exploration: 0.01, score: 177
# Scores: (min: 9, avg: 66.39473684210526, max: 177)
#
# Run: 39, exploration: 0.01, score: 228
# Scores: (min: 9, avg: 70.53846153846153, max: 228)
#
# Run: 40, exploration: 0.01, score: 195
# Scores: (min: 9, avg: 73.65, max: 228)
#
# Run: 41, exploration: 0.01, score: 180
# Scores: (min: 9, avg: 76.2439024390244, max: 228)
#
# Run: 42, exploration: 0.01, score: 233
# Scores: (min: 9, avg: 79.97619047619048, max: 233)
#
# Run: 43, exploration: 0.01, score: 191
# Scores: (min: 9, avg: 82.55813953488372, max: 233)
#
# Run: 44, exploration: 0.01, score: 171
# Scores: (min: 9, avg: 84.56818181818181, max: 233)
#
# Run: 45, exploration: 0.01, score: 354
# Scores: (min: 9, avg: 90.55555555555556, max: 354)
#
# Run: 46, exploration: 0.01, score: 212
# Scores: (min: 9, avg: 93.19565217391305, max: 354)
#
# Run: 47, exploration: 0.01, score: 179
# Scores: (min: 9, avg: 95.02127659574468, max: 354)
#
# Run: 48, exploration: 0.01, score: 171
# Scores: (min: 9, avg: 96.60416666666667, max: 354)
#
# Run: 49, exploration: 0.01, score: 191
# Scores: (min: 9, avg: 98.53061224489795, max: 354)
#
# Run: 50, exploration: 0.01, score: 222
# Scores: (min: 9, avg: 101, max: 354)
#
# Run: 51, exploration: 0.01, score: 168
# Scores: (min: 9, avg: 102.31372549019608, max: 354)
#
# Run: 52, exploration: 0.01, score: 150
# Scores: (min: 9, avg: 103.23076923076923, max: 354)
#
# Run: 53, exploration: 0.01, score: 216
# Scores: (min: 9, avg: 105.35849056603773, max: 354)
#
# Run: 54, exploration: 0.01, score: 238
# Scores: (min: 9, avg: 107.81481481481481, max: 354)
#
# Run: 55, exploration: 0.01, score: 172
# Scores: (min: 9, avg: 108.98181818181818, max: 354)
#
# Run: 56, exploration: 0.01, score: 348
# Scores: (min: 9, avg: 113.25, max: 354)
#
# Run: 57, exploration: 0.01, score: 205
# Scores: (min: 9, avg: 114.85964912280701, max: 354)
#
# Run: 58, exploration: 0.01, score: 194
# Scores: (min: 9, avg: 116.22413793103448, max: 354)
#
# Run: 59, exploration: 0.01, score: 200
# Scores: (min: 9, avg: 117.64406779661017, max: 354)
#
# Run: 60, exploration: 0.01, score: 303
# Scores: (min: 9, avg: 120.73333333333333, max: 354)
#
# Run: 61, exploration: 0.01, score: 152
# Scores: (min: 9, avg: 121.24590163934427, max: 354)
#
# Run: 62, exploration: 0.01, score: 169
# Scores: (min: 9, avg: 122.01612903225806, max: 354)
#
# Run: 63, exploration: 0.01, score: 216
# Scores: (min: 9, avg: 123.5079365079365, max: 354)
#
# Run: 64, exploration: 0.01, score: 178
# Scores: (min: 9, avg: 124.359375, max: 354)
#
# Run: 65, exploration: 0.01, score: 165
# Scores: (min: 9, avg: 124.98461538461538, max: 354)
#
# Run: 66, exploration: 0.01, score: 171
# Scores: (min: 9, avg: 125.68181818181819, max: 354)
#
# Run: 67, exploration: 0.01, score: 174
# Scores: (min: 9, avg: 126.40298507462687, max: 354)
#
# Run: 68, exploration: 0.01, score: 195
# Scores: (min: 9, avg: 127.41176470588235, max: 354)
#
# Run: 69, exploration: 0.01, score: 148
# Scores: (min: 9, avg: 127.71014492753623, max: 354)
#
# Run: 70, exploration: 0.01, score: 91
# Scores: (min: 9, avg: 127.18571428571428, max: 354)
#
# Run: 71, exploration: 0.01, score: 182
# Scores: (min: 9, avg: 127.95774647887323, max: 354)
#
# Run: 72, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 133.125, max: 500)
#
# Run: 73, exploration: 0.01, score: 162
# Scores: (min: 9, avg: 133.5205479452055, max: 500)
#
# Run: 74, exploration: 0.01, score: 172
# Scores: (min: 9, avg: 134.04054054054055, max: 500)
#
# Run: 75, exploration: 0.01, score: 159
# Scores: (min: 9, avg: 134.37333333333333, max: 500)
#
# Run: 76, exploration: 0.01, score: 112
# Scores: (min: 9, avg: 134.07894736842104, max: 500)
#
# Run: 77, exploration: 0.01, score: 263
# Scores: (min: 9, avg: 135.75324675324674, max: 500)
#
# Run: 78, exploration: 0.01, score: 165
# Scores: (min: 9, avg: 136.12820512820514, max: 500)
#
# Run: 79, exploration: 0.01, score: 156
# Scores: (min: 9, avg: 136.37974683544303, max: 500)
#
# Run: 80, exploration: 0.01, score: 159
# Scores: (min: 9, avg: 136.6625, max: 500)
#
# Run: 81, exploration: 0.01, score: 213
# Scores: (min: 9, avg: 137.60493827160494, max: 500)
#
# Run: 82, exploration: 0.01, score: 213
# Scores: (min: 9, avg: 138.52439024390245, max: 500)
#
# Run: 83, exploration: 0.01, score: 63
# Scores: (min: 9, avg: 137.6144578313253, max: 500)
#
# Run: 84, exploration: 0.01, score: 199
# Scores: (min: 9, avg: 138.3452380952381, max: 500)
#
# Run: 85, exploration: 0.01, score: 279
# Scores: (min: 9, avg: 140, max: 500)
#
# Run: 86, exploration: 0.01, score: 243
# Scores: (min: 9, avg: 141.19767441860466, max: 500)
#
# Run: 87, exploration: 0.01, score: 104
# Scores: (min: 9, avg: 140.77011494252875, max: 500)
#
# Run: 88, exploration: 0.01, score: 261
# Scores: (min: 9, avg: 142.13636363636363, max: 500)
#
# Run: 89, exploration: 0.01, score: 340
# Scores: (min: 9, avg: 144.35955056179776, max: 500)
#
# Run: 90, exploration: 0.01, score: 255
# Scores: (min: 9, avg: 145.5888888888889, max: 500)
# Run: 91, exploration: 0.01, score: 268
# Scores: (min: 9, avg: 146.93406593406593, max: 500)
#
# Run: 92, exploration: 0.01, score: 433
# Scores: (min: 9, avg: 150.04347826086956, max: 500)
# C:\ProgramData\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.110184). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# Run: 93, exploration: 0.01, score: 325
# Scores: (min: 9, avg: 151.9247311827957, max: 500)
#
# Run: 94, exploration: 0.01, score: 159
# Scores: (min: 9, avg: 152, max: 500)
#
# Run: 95, exploration: 0.01, score: 174
# Scores: (min: 9, avg: 152.23157894736843, max: 500)
#
# Run: 96, exploration: 0.01, score: 148
# Scores: (min: 9, avg: 152.1875, max: 500)
#
# Run: 97, exploration: 0.01, score: 45
# Scores: (min: 9, avg: 151.08247422680412, max: 500)
#
# Run: 98, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 149.66326530612244, max: 500)
#
# Run: 99, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 148.2929292929293, max: 500)
#
# Run: 100, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 146.94, max: 500)
#
# Run: 101, exploration: 0.01, score: 270
# Scores: (min: 9, avg: 149.21, max: 500)
#
# Run: 102, exploration: 0.01, score: 220
# Scores: (min: 9, avg: 151.27, max: 500)
#
# Run: 103, exploration: 0.01, score: 236
# Scores: (min: 9, avg: 153.37, max: 500)
#
# Run: 104, exploration: 0.01, score: 348
# Scores: (min: 9, avg: 156.6, max: 500)
#
# Run: 105, exploration: 0.01, score: 146
# Scores: (min: 9, avg: 157.91, max: 500)
#
# Run: 106, exploration: 0.01, score: 195
# Scores: (min: 9, avg: 159.66, max: 500)
#
# Run: 107, exploration: 0.01, score: 213
# Scores: (min: 9, avg: 161.68, max: 500)
#
# Run: 108, exploration: 0.01, score: 252
# Scores: (min: 9, avg: 164.09, max: 500)
#
# Run: 109, exploration: 0.01, score: 198
# Scores: (min: 9, avg: 165.9, max: 500)
#
# Run: 110, exploration: 0.01, score: 193
# Scores: (min: 9, avg: 167.62, max: 500)
#
# Run: 111, exploration: 0.01, score: 185
# Scores: (min: 9, avg: 169.37, max: 500)
#
# Run: 112, exploration: 0.01, score: 245
# Scores: (min: 9, avg: 171.7, max: 500)
#
# Run: 113, exploration: 0.01, score: 201
# Scores: (min: 9, avg: 173.59, max: 500)
#
# Run: 114, exploration: 0.01, score: 147
# Scores: (min: 10, avg: 174.97, max: 500)
#
# Run: 115, exploration: 0.01, score: 178
# Scores: (min: 10, avg: 176.65, max: 500)
#
# Run: 116, exploration: 0.01, score: 131
# Scores: (min: 11, avg: 177.86, max: 500)
#
# Run: 117, exploration: 0.01, score: 204
# Scores: (min: 11, avg: 179.75, max: 500)
#
# Run: 118, exploration: 0.01, score: 154
# Scores: (min: 12, avg: 181.18, max: 500)
#
# Run: 119, exploration: 0.01, score: 206
# Scores: (min: 12, avg: 182.23, max: 500)
#
# Run: 120, exploration: 0.01, score: 295
# Scores: (min: 12, avg: 184.16, max: 500)
#
# Run: 121, exploration: 0.01, score: 186
# Scores: (min: 12, avg: 184.45, max: 500)
#
# Run: 122, exploration: 0.01, score: 392
# Scores: (min: 12, avg: 186.75, max: 500)
#
# Run: 123, exploration: 0.01, score: 188
# Scores: (min: 12, avg: 187.25, max: 500)
#
# Run: 124, exploration: 0.01, score: 500
# Scores: (min: 12, avg: 190.95, max: 500)
#
# Run: 125, exploration: 0.01, score: 500
# Scores: (min: 12, avg: 194.8, max: 500)
#
# Run: 126, exploration: 0.01, score: 173
# Scores: (min: 12, avg: 195.61, max: 500)
#
# Solved in 26 runs, 126 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-1-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
GAMMA = 0.99 # Higher discount factor allowed for more consistency, program took longer
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 19
# Scores: (min: 19, avg: 19, max: 19)
#
# Run: 2, exploration: 0.8955869907338783, score: 23
# Scores: (min: 19, avg: 21, max: 23)
#
# Run: 3, exploration: 0.8603841919146962, score: 9
# Scores: (min: 9, avg: 17, max: 23)
#
# Run: 4, exploration: 0.8183201210226743, score: 11
# Scores: (min: 9, avg: 15.5, max: 23)
#
# Run: 5, exploration: 0.7219385759785162, score: 26
# Scores: (min: 9, avg: 17.6, max: 26)
#
# Run: 6, exploration: 0.6662995813682115, score: 17
# Scores: (min: 9, avg: 17.5, max: 26)
#
# Run: 7, exploration: 0.6305556603555866, score: 12
# Scores: (min: 9, avg: 16.714285714285715, max: 26)
#
# Run: 8, exploration: 0.5647174463480732, score: 23
# Scores: (min: 9, avg: 17.5, max: 26)
#
# Run: 9, exploration: 0.4529463432347434, score: 45
# Scores: (min: 9, avg: 20.555555555555557, max: 45)
#
# Run: 10, exploration: 0.4286478463299511, score: 12
# Scores: (min: 9, avg: 19.7, max: 45)
#
# Run: 11, exploration: 0.40769130904675194, score: 11
# Scores: (min: 9, avg: 18.90909090909091, max: 45)
#
# Run: 12, exploration: 0.37627099809304654, score: 17
# Scores: (min: 9, avg: 18.75, max: 45)
#
# Run: 13, exploration: 0.1903004112552766, score: 137
# Scores: (min: 9, avg: 27.846153846153847, max: 137)
#
# Run: 14, exploration: 0.14444721332374086, score: 56
# Scores: (min: 9, avg: 29.857142857142858, max: 137)
#
# Run: 15, exploration: 0.10119240105273684, score: 72
# Scores: (min: 9, avg: 32.666666666666664, max: 137)
#
# Run: 16, exploration: 0.05714511431233153, score: 115
# Scores: (min: 9, avg: 37.8125, max: 137)
#
# Run: 17, exploration: 0.043812938841152796, score: 54
# Scores: (min: 9, avg: 38.76470588235294, max: 137)
#
# Run: 18, exploration: 0.03325613897196732, score: 56
# Scores: (min: 9, avg: 39.72222222222222, max: 137)
#
# Run: 19, exploration: 0.027350922279685573, score: 40
# Scores: (min: 9, avg: 39.73684210526316, max: 137)
#
# Run: 20, exploration: 0.022047758717570132, score: 44
# Scores: (min: 9, avg: 39.95, max: 137)
#
# Run: 21, exploration: 0.01724627885940145, score: 50
# Scores: (min: 9, avg: 40.42857142857143, max: 137)
#
# Run: 22, exploration: 0.013694844909292236, score: 47
# Scores: (min: 9, avg: 40.72727272727273, max: 137)
#
# Run: 23, exploration: 0.010658869760009713, score: 51
# Scores: (min: 9, avg: 41.17391304347826, max: 137)
#
# Run: 24, exploration: 0.01, score: 33
# Scores: (min: 9, avg: 40.833333333333336, max: 137)
#
# Run: 25, exploration: 0.01, score: 61
# Scores: (min: 9, avg: 41.64, max: 137)
#
# Run: 26, exploration: 0.01, score: 46
# Scores: (min: 9, avg: 41.80769230769231, max: 137)
#
# Run: 27, exploration: 0.01, score: 42
# Scores: (min: 9, avg: 41.81481481481482, max: 137)
#
# Run: 28, exploration: 0.01, score: 66
# Scores: (min: 9, avg: 42.67857142857143, max: 137)
#
# Run: 29, exploration: 0.01, score: 34
# Scores: (min: 9, avg: 42.37931034482759, max: 137)
#
# Run: 30, exploration: 0.01, score: 37
# Scores: (min: 9, avg: 42.2, max: 137)
#
# Run: 31, exploration: 0.01, score: 46
# Scores: (min: 9, avg: 42.32258064516129, max: 137)
#
# Run: 32, exploration: 0.01, score: 48
# Scores: (min: 9, avg: 42.5, max: 137)
#
# Run: 33, exploration: 0.01, score: 44
# Scores: (min: 9, avg: 42.54545454545455, max: 137)
#
# Run: 34, exploration: 0.01, score: 69
# Scores: (min: 9, avg: 43.3235294117647, max: 137)
#
# Run: 35, exploration: 0.01, score: 37
# Scores: (min: 9, avg: 43.142857142857146, max: 137)
#
# Run: 36, exploration: 0.01, score: 101
# Scores: (min: 9, avg: 44.75, max: 137)
#
# Run: 37, exploration: 0.01, score: 75
# Scores: (min: 9, avg: 45.567567567567565, max: 137)
#
# Run: 38, exploration: 0.01, score: 26
# Scores: (min: 9, avg: 45.05263157894737, max: 137)
#
# Run: 39, exploration: 0.01, score: 35
# Scores: (min: 9, avg: 44.794871794871796, max: 137)
#
# Run: 40, exploration: 0.01, score: 50
# Scores: (min: 9, avg: 44.925, max: 137)
#
# Run: 41, exploration: 0.01, score: 48
# Scores: (min: 9, avg: 45, max: 137)
#
# Run: 42, exploration: 0.01, score: 97
# Scores: (min: 9, avg: 46.23809523809524, max: 137)
#
# Run: 43, exploration: 0.01, score: 177
# Scores: (min: 9, avg: 49.27906976744186, max: 177)
#
# Run: 44, exploration: 0.01, score: 245
# Scores: (min: 9, avg: 53.72727272727273, max: 245)
#
# Run: 45, exploration: 0.01, score: 43
# Scores: (min: 9, avg: 53.48888888888889, max: 245)
#
# Run: 46, exploration: 0.01, score: 43
# Scores: (min: 9, avg: 53.26086956521739, max: 245)
#
# Run: 47, exploration: 0.01, score: 71
# Scores: (min: 9, avg: 53.638297872340424, max: 245)
#
# Run: 48, exploration: 0.01, score: 202
# Scores: (min: 9, avg: 56.729166666666664, max: 245)
#
# Run: 49, exploration: 0.01, score: 287
# Scores: (min: 9, avg: 61.42857142857143, max: 287)
#
# Run: 50, exploration: 0.01, score: 375
# Scores: (min: 9, avg: 67.7, max: 375)
#
# Run: 51, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 76.17647058823529, max: 500)
#
# Run: 52, exploration: 0.01, score: 466
# Scores: (min: 9, avg: 83.67307692307692, max: 500)
#
# Run: 53, exploration: 0.01, score: 329
# Scores: (min: 9, avg: 88.30188679245283, max: 500)
#
# Run: 54, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 95.92592592592592, max: 500)
#
# Run: 55, exploration: 0.01, score: 286
# Scores: (min: 9, avg: 99.38181818181818, max: 500)
#
# Run: 56, exploration: 0.01, score: 229
# Scores: (min: 9, avg: 101.69642857142857, max: 500)
#
# Run: 57, exploration: 0.01, score: 227
# Scores: (min: 9, avg: 103.89473684210526, max: 500)
#
# Run: 58, exploration: 0.01, score: 200
# Scores: (min: 9, avg: 105.55172413793103, max: 500)
#
# Run: 59, exploration: 0.01, score: 251
# Scores: (min: 9, avg: 108.01694915254237, max: 500)
#
# Run: 60, exploration: 0.01, score: 304
# Scores: (min: 9, avg: 111.28333333333333, max: 500)
#
# Run: 61, exploration: 0.01, score: 299
# Scores: (min: 9, avg: 114.36065573770492, max: 500)
#
# Run: 62, exploration: 0.01, score: 275
# Scores: (min: 9, avg: 116.95161290322581, max: 500)
#
# Run: 63, exploration: 0.01, score: 399
# Scores: (min: 9, avg: 121.42857142857143, max: 500)
#
# Run: 64, exploration: 0.01, score: 488
# Scores: (min: 9, avg: 127.15625, max: 500)
#
# Run: 65, exploration: 0.01, score: 399
# Scores: (min: 9, avg: 131.33846153846153, max: 500)
#
# Run: 66, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 136.92424242424244, max: 500)
#
# Run: 67, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 142.34328358208955, max: 500)
#
# Run: 68, exploration: 0.01, score: 438
# Scores: (min: 9, avg: 146.69117647058823, max: 500)
#
# Run: 69, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 151.81159420289856, max: 500)
#
# Run: 70, exploration: 0.01, score: 142
# Scores: (min: 9, avg: 151.67142857142858, max: 500)
#
# Run: 71, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 149.70422535211267, max: 500)
#
# Run: 72, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 147.77777777777777, max: 500)
#
# Run: 73, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 145.8904109589041, max: 500)
#
# Run: 74, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 144.04054054054055, max: 500)
#
# Run: 75, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 142.25333333333333, max: 500)
#
# Run: 76, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 140.51315789473685, max: 500)
#
# Run: 77, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 138.8181818181818, max: 500)
#
# Run: 78, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 137.15384615384616, max: 500)
#
# Run: 79, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 135.55696202531647, max: 500)
#
# Run: 80, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 133.9875, max: 500)
#
# Run: 81, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 132.50617283950618, max: 500)
#
# Run: 82, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 131.03658536585365, max: 500)
#
# Run: 83, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 129.57831325301206, max: 500)
#
# Run: 84, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 128.1904761904762, max: 500)
#
# Run: 85, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 126.85882352941177, max: 500)
#
# Run: 86, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 125.55813953488372, max: 500)
#
# Run: 87, exploration: 0.01, score: 134
# Scores: (min: 9, avg: 125.65517241379311, max: 500)
#
# Run: 88, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 129.9090909090909, max: 500)
#
# Run: 89, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 134.06741573033707, max: 500)
#
# Run: 90, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 138.13333333333333, max: 500)
# Run: 91, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 142.1098901098901, max: 500)
#
# Run: 92, exploration: 0.01, score: 355
# Scores: (min: 9, avg: 144.42391304347825, max: 500)
#
# Run: 93, exploration: 0.01, score: 305
# Scores: (min: 9, avg: 146.1505376344086, max: 500)
#
# Run: 94, exploration: 0.01, score: 218
# Scores: (min: 9, avg: 146.91489361702128, max: 500)
#
# Run: 95, exploration: 0.01, score: 274
# Scores: (min: 9, avg: 148.25263157894736, max: 500)
#
# Run: 96, exploration: 0.01, score: 299
# Scores: (min: 9, avg: 149.82291666666666, max: 500)
#
# Run: 97, exploration: 0.01, score: 389
# Scores: (min: 9, avg: 152.28865979381445, max: 500)
#
# Run: 98, exploration: 0.01, score: 401
# Scores: (min: 9, avg: 154.8265306122449, max: 500)
#
# Run: 99, exploration: 0.01, score: 260
# Scores: (min: 9, avg: 155.88888888888889, max: 500)
#
# Run: 100, exploration: 0.01, score: 481
# Scores: (min: 9, avg: 159.14, max: 500)
#
# Run: 101, exploration: 0.01, score: 230
# Scores: (min: 9, avg: 161.25, max: 500)
#
# Run: 102, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 166.02, max: 500)
#
# Run: 103, exploration: 0.01, score: 343
# Scores: (min: 9, avg: 169.36, max: 500)
#
# Run: 104, exploration: 0.01, score: 408
# Scores: (min: 9, avg: 173.33, max: 500)
#
# Run: 105, exploration: 0.01, score: 413
# Scores: (min: 9, avg: 177.2, max: 500)
#
# Run: 106, exploration: 0.01, score: 265
# Scores: (min: 9, avg: 179.68, max: 500)
#
# Run: 107, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 179.66, max: 500)
#
# Run: 108, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 179.53, max: 500)
#
# Run: 109, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 179.18, max: 500)
#
# Run: 110, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 179.16, max: 500)
#
# Run: 111, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 179.15, max: 500)
#
# Run: 112, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 179.07, max: 500)
#
# Run: 113, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 177.8, max: 500)
#
# Run: 114, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 177.32, max: 500)
#
# Run: 115, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 176.7, max: 500)
#
# Run: 116, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 175.65, max: 500)
#
# Run: 117, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 175.2, max: 500)
#
# Run: 118, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 174.73, max: 500)
#
# Run: 119, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 174.44, max: 500)
#
# Run: 120, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 174.09, max: 500)
#
# Run: 121, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 173.67, max: 500)
#
# Run: 122, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 173.28, max: 500)
#
# Run: 123, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 172.86, max: 500)
#
# Run: 124, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 172.61, max: 500)
#
# Run: 125, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 172.08, max: 500)
#
# Run: 126, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 171.72, max: 500)
#
# Run: 127, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 171.39, max: 500)
#
# Run: 128, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 170.83, max: 500)
#
# Run: 129, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 170.59, max: 500)
#
# Run: 130, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 170.3, max: 500)
#
# Run: 131, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 169.93, max: 500)
#
# Run: 132, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 169.54, max: 500)
#
# Run: 133, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 169.2, max: 500)
#
# Run: 134, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 168.62, max: 500)
#
# Run: 135, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 168.34, max: 500)
#
# Run: 136, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 167.43, max: 500)
#
# Run: 137, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 166.77, max: 500)
#
# Run: 138, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 166.6, max: 500)
#
# Run: 139, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 166.33, max: 500)
#
# Run: 140, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 165.93, max: 500)
#
# Run: 141, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 165.54, max: 500)
#
# Run: 142, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 164.66, max: 500)
#
# Run: 143, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 162.98, max: 500)
#
# Run: 144, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 160.62, max: 500)
#
# Run: 145, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 160.28, max: 500)
#
# Run: 146, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 159.94, max: 500)
#
# Run: 147, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 159.34, max: 500)
#
# Run: 148, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 157.41, max: 500)
#
# Run: 149, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 154.63, max: 500)
#
# Run: 150, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 150.97, max: 500)
#
# Run: 151, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 146.06, max: 500)
#
# Run: 152, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 141.5, max: 500)
#
# Run: 153, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 138.31, max: 500)
#
# Run: 154, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 133.41, max: 500)
#
# Run: 155, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 130.64, max: 500)
#
# Run: 156, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 128.44, max: 500)
#
# Run: 157, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 126.26, max: 500)
#
# Run: 158, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 124.34, max: 500)
#
# Run: 159, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 121.93, max: 500)
#
# Run: 160, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 118.98, max: 500)
#
# Run: 161, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 116.08, max: 500)
#
# Run: 162, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 113.42, max: 500)
#
# Run: 163, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 109.53, max: 500)
#
# Run: 164, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 104.75, max: 500)
#
# Run: 165, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 100.86, max: 500)
#
# Run: 166, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 95.96, max: 500)
#
# Run: 167, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 91.06, max: 500)
#
# Run: 168, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 86.77, max: 500)
#
# Run: 169, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 81.86, max: 500)
#
# Run: 170, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 80.52, max: 500)
#
# Run: 171, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 80.5, max: 500)
#
# Run: 172, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 80.5, max: 500)
#
# Run: 173, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 80.49, max: 500)
#
# Run: 174, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 80.5, max: 500)
#
# Run: 175, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 80.5, max: 500)
#
# Run: 176, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 80.5, max: 500)
#
# Run: 177, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 80.48, max: 500)
#
# Run: 178, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 80.48, max: 500)
#
# Run: 179, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 80.47, max: 500)
#
# Run: 180, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 80.45, max: 500)
#
# Run: 181, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 80.4, max: 500)
#
# Run: 182, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 80.38, max: 500)
#
# Run: 183, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 80.38, max: 500)
#
# Run: 184, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 80.34, max: 500)
#
# Run: 185, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 80.28, max: 500)
#
# Run: 186, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 80.22, max: 500)
#
# Run: 187, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 78.97, max: 500)
#
# Run: 188, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 74.07, max: 500)
#
# Run: 189, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 69.17, max: 500)
#
# Run: 190, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 64.27, max: 500)
#
# Run: 191, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 59.37, max: 500)
#
# Run: 192, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 55.92, max: 500)
#
# Run: 193, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 52.96, max: 500)
# Run: 194, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 50.89, max: 500)
#
# Run: 195, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 48.26, max: 500)
#
# Run: 196, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 45.36, max: 500)
#
# Run: 197, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 41.62, max: 500)
#
# Run: 198, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 37.71, max: 500)
#
# Run: 199, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 35.2, max: 500)
#
# Run: 200, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 30.47, max: 500)
#
# Run: 201, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 28.25, max: 500)
#
# Run: 202, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 23.34, max: 413)
#
# Run: 203, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 20.02, max: 413)
#
# Run: 204, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.03, max: 413)
#
# Run: 205, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12, max: 265)
#
# Run: 206, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.45, max: 15)
#
# Run: 207, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.44, max: 15)
#
# Run: 208, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.43, max: 15)
#
# Run: 209, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.41, max: 15)
#
# Run: 210, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.4, max: 15)
#
# Run: 211, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.39, max: 15)
#
# Run: 212, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.38, max: 15)
#
# Run: 213, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.37, max: 15)
#
# Run: 214, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.38, max: 15)
#
# Run: 215, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.37, max: 15)
#
# Run: 216, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.35, max: 15)
#
# Run: 217, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.35, max: 15)
#
# Run: 218, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.34, max: 15)
#
# Run: 219, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.32, max: 15)
#
# Run: 220, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.32, max: 15)
#
# Run: 221, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.33, max: 15)
#
# Run: 222, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.34, max: 15)
#
# Run: 223, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.35, max: 15)
#
# Run: 224, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.37, max: 15)
#
# Run: 225, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.38, max: 15)
#
# Run: 226, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.38, max: 15)
#
# Run: 227, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.39, max: 15)
#
# Run: 228, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.39, max: 15)
#
# Run: 229, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.38, max: 15)
#
# Run: 230, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 9.41, max: 15)
#
# Run: 231, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.4, max: 15)
#
# Run: 232, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.4, max: 15)
#
# Run: 233, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.4, max: 15)
#
# Run: 234, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.39, max: 15)
#
# Run: 235, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.39, max: 15)
#
# Run: 236, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.37, max: 15)
#
# Run: 237, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.37, max: 15)
#
# Run: 238, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.38, max: 15)
#
# Run: 239, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.4, max: 15)
#
# Run: 240, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.39, max: 15)
#
# Run: 241, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.39, max: 15)
#
# Run: 242, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.4, max: 15)
#
# Run: 243, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.4, max: 15)
#
# Run: 244, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.39, max: 15)
#
# Run: 245, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.4, max: 15)
#
# Run: 246, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.4, max: 15)
#
# Run: 247, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.39, max: 15)
#
# Run: 248, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.39, max: 15)
#
# Run: 249, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.4, max: 15)
#
# Run: 250, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.4, max: 15)
#
# Run: 251, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.4, max: 15)
#
# Run: 252, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.4, max: 15)
#
# Run: 253, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.4, max: 15)
#
# Run: 254, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.39, max: 15)
#
# Run: 255, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.4, max: 15)
#
# Run: 256, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.41, max: 15)
#
# Run: 257, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.4, max: 15)
#
# Run: 258, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.41, max: 15)
#
# Run: 259, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.4, max: 15)
#
# Run: 260, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.41, max: 15)
#
# Run: 261, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.42, max: 15)
#
# Run: 262, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.43, max: 15)
#
# Run: 263, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.41, max: 15)
#
# Run: 264, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.41, max: 15)
#
# Run: 265, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.4, max: 15)
#
# Run: 266, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.4, max: 15)
#
# Run: 267, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.39, max: 15)
#
# Run: 268, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.39, max: 15)
#
# Run: 269, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.39, max: 15)
#
# Run: 270, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.39, max: 15)
#
# Run: 271, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.38, max: 15)
#
# Run: 272, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.37, max: 15)
#
# Run: 273, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.38, max: 15)
#
# Run: 274, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.38, max: 15)
#
# Run: 275, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.38, max: 15)
#
# Run: 276, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.38, max: 15)
#
# Run: 277, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.4, max: 15)
#
# Run: 278, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.39, max: 15)
#
# Run: 279, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.39, max: 15)
#
# Run: 280, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.4, max: 15)
#
# Run: 281, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.39, max: 15)
#
# Run: 282, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.38, max: 15)
#
# Run: 283, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.37, max: 15)
#
# Run: 284, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.38, max: 15)
#
# Run: 285, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.39, max: 15)
#
# Run: 286, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.39, max: 15)
#
# Run: 287, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.39, max: 15)
#
# Run: 288, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.38, max: 15)
#
# Run: 289, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.37, max: 15)
#
# Run: 290, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.36, max: 15)
#
# Run: 291, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.35, max: 15)
#
# Run: 292, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.34, max: 15)
#
# Run: 293, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 9.36, max: 15)
#
# Run: 294, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.35, max: 15)
#
# Run: 295, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.34, max: 15)
#
# Run: 296, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.35, max: 15)
#
# Run: 297, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 9.32, max: 12)
#
# Run: 298, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 9.33, max: 12)
#
# Run: 299, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 9.37, max: 13)
#
# Run: 300, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.39, max: 13)
#
# Run: 301, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.41, max: 13)
# Run: 302, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.41, max: 13)
#
# Run: 303, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 9.41, max: 13)
#
# Run: 304, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 9.43, max: 13)
#
# Run: 305, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.43, max: 13)
#
# Run: 306, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.43, max: 13)
#
# Run: 307, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.44, max: 13)
#
# Run: 308, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 9.46, max: 13)
#
# Run: 309, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 9.57, max: 19)
#
# Run: 310, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 9.66, max: 19)
#
# Run: 311, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.67, max: 19)
#
# Run: 312, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.69, max: 19)
#
# Run: 313, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.7, max: 19)
#
# Run: 314, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.7, max: 19)
#
# Run: 315, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 9.72, max: 19)
#
# Run: 316, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 9.77, max: 19)
#
# Run: 317, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.77, max: 19)
#
# Run: 318, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 9.81, max: 19)
#
# Run: 319, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 9.84, max: 19)
#
# Run: 320, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 9.91, max: 19)
#
# Run: 321, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 9.95, max: 19)
#
# Run: 322, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 9.99, max: 19)
#
# Run: 323, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.01, max: 19)
#
# Run: 324, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.03, max: 19)
#
# Run: 325, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 10.13, max: 19)
#
# Run: 326, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 10.29, max: 26)
#
# Run: 327, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 10.51, max: 32)
#
# Run: 328, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 10.67, max: 32)
#
# Run: 329, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 10.99, max: 41)
#
# Run: 330, exploration: 0.01, score: 66
# Scores: (min: 8, avg: 11.54, max: 66)
#
# Run: 331, exploration: 0.01, score: 69
# Scores: (min: 8, avg: 12.15, max: 69)
#
# Run: 332, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 12.5, max: 69)
#
# Run: 333, exploration: 0.01, score: 70
# Scores: (min: 8, avg: 13.1, max: 70)
#
# Run: 334, exploration: 0.01, score: 71
# Scores: (min: 8, avg: 13.71, max: 71)
#
# Run: 335, exploration: 0.01, score: 91
# Scores: (min: 8, avg: 14.53, max: 91)
#
# Run: 336, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 14.99, max: 91)
#
# Run: 337, exploration: 0.01, score: 143
# Scores: (min: 8, avg: 16.33, max: 143)
#
# Run: 338, exploration: 0.01, score: 155
# Scores: (min: 8, avg: 17.78, max: 155)
#
# Run: 339, exploration: 0.01, score: 72
# Scores: (min: 8, avg: 18.4, max: 155)
#
# Run: 340, exploration: 0.01, score: 83
# Scores: (min: 8, avg: 19.14, max: 155)
#
# Run: 341, exploration: 0.01, score: 103
# Scores: (min: 8, avg: 20.08, max: 155)
#
# Run: 342, exploration: 0.01, score: 100
# Scores: (min: 8, avg: 20.98, max: 155)
#
# Run: 343, exploration: 0.01, score: 105
# Scores: (min: 8, avg: 21.94, max: 155)
#
# Run: 344, exploration: 0.01, score: 76
# Scores: (min: 8, avg: 22.62, max: 155)
#
# Run: 345, exploration: 0.01, score: 84
# Scores: (min: 8, avg: 23.36, max: 155)
#
# Run: 346, exploration: 0.01, score: 110
# Scores: (min: 8, avg: 24.37, max: 155)
#
# Run: 347, exploration: 0.01, score: 151
# Scores: (min: 8, avg: 25.78, max: 155)
#
# Run: 348, exploration: 0.01, score: 203
# Scores: (min: 8, avg: 27.72, max: 203)
#
# Run: 349, exploration: 0.01, score: 130
# Scores: (min: 8, avg: 28.92, max: 203)
#
# Run: 350, exploration: 0.01, score: 172
# Scores: (min: 8, avg: 30.55, max: 203)
#
# Run: 351, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 35.46, max: 500)
#
# Run: 352, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 40.36, max: 500)
#
# Run: 353, exploration: 0.01, score: 156
# Scores: (min: 8, avg: 41.82, max: 500)
#
# Run: 354, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 46.73, max: 500)
#
# Run: 355, exploration: 0.01, score: 159
# Scores: (min: 8, avg: 48.22, max: 500)
#
# Run: 356, exploration: 0.01, score: 157
# Scores: (min: 8, avg: 49.69, max: 500)
#
# Run: 357, exploration: 0.01, score: 140
# Scores: (min: 8, avg: 51.01, max: 500)
#
# Run: 358, exploration: 0.01, score: 164
# Scores: (min: 8, avg: 52.56, max: 500)
#
# Run: 359, exploration: 0.01, score: 173
# Scores: (min: 8, avg: 54.2, max: 500)
#
# Run: 360, exploration: 0.01, score: 156
# Scores: (min: 8, avg: 55.66, max: 500)
#
# Run: 361, exploration: 0.01, score: 186
# Scores: (min: 8, avg: 57.42, max: 500)
#
# Run: 362, exploration: 0.01, score: 150
# Scores: (min: 8, avg: 58.82, max: 500)
#
# Run: 363, exploration: 0.01, score: 118
# Scores: (min: 8, avg: 59.92, max: 500)
#
# Run: 364, exploration: 0.01, score: 350
# Scores: (min: 8, avg: 63.32, max: 500)
#
# Run: 365, exploration: 0.01, score: 104
# Scores: (min: 8, avg: 64.27, max: 500)
#
# Run: 366, exploration: 0.01, score: 95
# Scores: (min: 8, avg: 65.12, max: 500)
#
# Run: 367, exploration: 0.01, score: 95
# Scores: (min: 8, avg: 65.98, max: 500)
#
# Run: 368, exploration: 0.01, score: 181
# Scores: (min: 8, avg: 67.7, max: 500)
#
# Run: 369, exploration: 0.01, score: 101
# Scores: (min: 8, avg: 68.62, max: 500)
#
# Run: 370, exploration: 0.01, score: 148
# Scores: (min: 8, avg: 70.02, max: 500)
#
# Run: 371, exploration: 0.01, score: 87
# Scores: (min: 8, avg: 70.8, max: 500)
#
# Run: 372, exploration: 0.01, score: 97
# Scores: (min: 8, avg: 71.67, max: 500)
#
# Run: 373, exploration: 0.01, score: 92
# Scores: (min: 8, avg: 72.49, max: 500)
#
# Run: 374, exploration: 0.01, score: 88
# Scores: (min: 8, avg: 73.27, max: 500)
#
# Run: 375, exploration: 0.01, score: 95
# Scores: (min: 8, avg: 74.12, max: 500)
#
# Run: 376, exploration: 0.01, score: 135
# Scores: (min: 8, avg: 75.37, max: 500)
#
# Run: 377, exploration: 0.01, score: 111
# Scores: (min: 8, avg: 76.38, max: 500)
#
# Run: 378, exploration: 0.01, score: 120
# Scores: (min: 8, avg: 77.5, max: 500)
#
# Run: 379, exploration: 0.01, score: 107
# Scores: (min: 8, avg: 78.47, max: 500)
#
# Run: 380, exploration: 0.01, score: 149
# Scores: (min: 8, avg: 79.87, max: 500)
#
# Run: 381, exploration: 0.01, score: 141
# Scores: (min: 9, avg: 81.2, max: 500)
#
# Run: 382, exploration: 0.01, score: 191
# Scores: (min: 9, avg: 83.02, max: 500)
#
# Run: 383, exploration: 0.01, score: 346
# Scores: (min: 9, avg: 86.39, max: 500)
#
# Run: 384, exploration: 0.01, score: 316
# Scores: (min: 9, avg: 89.45, max: 500)
#
# Run: 385, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 94.35, max: 500)
#
# Run: 386, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 99.26, max: 500)
#
# Run: 387, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 104.17, max: 500)
#
# Run: 388, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 109.08, max: 500)
#
# Run: 389, exploration: 0.01, score: 178
# Scores: (min: 9, avg: 110.77, max: 500)
#
# Run: 390, exploration: 0.01, score: 207
# Scores: (min: 9, avg: 112.75, max: 500)
#
# Run: 391, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 117.66, max: 500)
#
# Run: 392, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 122.57, max: 500)
#
# Run: 393, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 122.55, max: 500)
#
# Run: 394, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 122.54, max: 500)
#
# Run: 395, exploration: 0.01, score: 249
# Scores: (min: 9, avg: 124.93, max: 500)
#
# Run: 396, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 129.83, max: 500)
#
# Run: 397, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 134.71, max: 500)
#
# Run: 398, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 139.6, max: 500)
#
# Run: 399, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 144.47, max: 500)
#
# Run: 400, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 149.37, max: 500)
#
# Run: 401, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 154.27, max: 500)
#
# Run: 402, exploration: 0.01, score: 230
# Scores: (min: 9, avg: 156.48, max: 500)
#
# Run: 403, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 161.37, max: 500)
#
# Run: 404, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 166.26, max: 500)
#
# Run: 405, exploration: 0.01, score: 470
# Scores: (min: 9, avg: 170.86, max: 500)
# Run: 406, exploration: 0.01, score: 476
# Scores: (min: 9, avg: 175.52, max: 500)
#
# Run: 407, exploration: 0.01, score: 448
# Scores: (min: 9, avg: 179.9, max: 500)
#
# Run: 408, exploration: 0.01, score: 406
# Scores: (min: 9, avg: 183.85, max: 500)
#
# Run: 409, exploration: 0.01, score: 339
# Scores: (min: 9, avg: 187.05, max: 500)
#
# Run: 410, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 191.87, max: 500)
#
# Run: 411, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 196.77, max: 500)
#
# Solved in 311 runs, 411 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-d4cbd4f1daea> in <module>
#       1 GAMMA = 0.99
# ----> 2 cartpole()
#
# <ipython-input-1-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
GAMMA = 0.50 #Stopped, I Dont think it will ever reach an average of 195 to end the program. Low discount factor = short sighted agen
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 19
# Scores: (min: 19, avg: 19, max: 19)
#
# Run: 2, exploration: 0.9511101304657719, score: 11
# Scores: (min: 11, avg: 15, max: 19)
#
# Run: 3, exploration: 0.8647077305675338, score: 20
# Scores: (min: 11, avg: 16.666666666666668, max: 20)
#
# Run: 4, exploration: 0.8265651079747222, score: 10
# Scores: (min: 10, avg: 15, max: 20)
#
# Run: 5, exploration: 0.7628626641409962, score: 17
# Scores: (min: 10, avg: 15.4, max: 20)
#
# Run: 6, exploration: 0.4858739637363176, score: 91
# Scores: (min: 10, avg: 28, max: 91)
#
# Run: 7, exploration: 0.42437208406280985, score: 28
# Scores: (min: 10, avg: 28, max: 91)
#
# Run: 8, exploration: 0.3877593341372176, score: 19
# Scores: (min: 10, avg: 26.875, max: 91)
#
# Run: 9, exploration: 0.3578751580867638, score: 17
# Scores: (min: 10, avg: 25.77777777777778, max: 91)
#
# Run: 10, exploration: 0.27164454854530906, score: 56
# Scores: (min: 10, avg: 28.8, max: 91)
#
# Run: 11, exploration: 0.2494556624678441, score: 18
# Scores: (min: 10, avg: 27.818181818181817, max: 91)
#
# Run: 12, exploration: 0.21462770857094118, score: 31
# Scores: (min: 10, avg: 28.083333333333332, max: 91)
#
# Run: 13, exploration: 0.18190617987607657, score: 34
# Scores: (min: 10, avg: 28.53846153846154, max: 91)
#
# Run: 14, exploration: 0.1678868750508869, score: 17
# Scores: (min: 10, avg: 27.714285714285715, max: 91)
#
# Run: 15, exploration: 0.1572956799768517, score: 14
# Scores: (min: 10, avg: 26.8, max: 91)
#
# Run: 16, exploration: 0.14016760486247823, score: 24
# Scores: (min: 10, avg: 26.625, max: 91)
#
# Run: 17, exploration: 0.10533270926593409, score: 58
# Scores: (min: 10, avg: 28.470588235294116, max: 91)
#
# Run: 18, exploration: 0.0996820918179746, score: 12
# Scores: (min: 10, avg: 27.555555555555557, max: 91)
#
# Run: 19, exploration: 0.0906265979439563, score: 20
# Scores: (min: 10, avg: 27.157894736842106, max: 91)
#
# Run: 20, exploration: 0.06285510723190912, score: 74
# Scores: (min: 10, avg: 29.5, max: 91)
#
# Run: 21, exploration: 0.05517478773284426, score: 27
# Scores: (min: 10, avg: 29.38095238095238, max: 91)
#
# Run: 22, exploration: 0.05092252885731386, score: 17
# Scores: (min: 10, avg: 28.818181818181817, max: 91)
#
# Run: 23, exploration: 0.048432933065126825, score: 11
# Scores: (min: 10, avg: 28.043478260869566, max: 91)
#
# Run: 24, exploration: 0.044924885780066794, score: 16
# Scores: (min: 10, avg: 27.541666666666668, max: 91)
#
# Run: 25, exploration: 0.043159025252331236, score: 9
# Scores: (min: 9, avg: 26.8, max: 91)
#
# Run: 26, exploration: 0.0378853869148274, score: 27
# Scores: (min: 9, avg: 26.807692307692307, max: 91)
#
# Run: 27, exploration: 0.029339239003388088, score: 52
# Scores: (min: 9, avg: 27.74074074074074, max: 91)
#
# Run: 28, exploration: 0.02260731802731653, score: 53
# Scores: (min: 9, avg: 28.642857142857142, max: 91)
#
# Run: 29, exploration: 0.020969846670345987, score: 16
# Scores: (min: 9, avg: 28.20689655172414, max: 91)
#
# Run: 30, exploration: 0.018686420266267767, score: 24
# Scores: (min: 9, avg: 28.066666666666666, max: 91)
#
# Run: 31, exploration: 0.01529147369377279, score: 41
# Scores: (min: 9, avg: 28.483870967741936, max: 91)
#
# Run: 32, exploration: 0.013289101019874787, score: 29
# Scores: (min: 9, avg: 28.5, max: 91)
#
# Run: 33, exploration: 0.011433732442257729, score: 31
# Scores: (min: 9, avg: 28.575757575757574, max: 91)
#
# Run: 34, exploration: 0.01, score: 38
# Scores: (min: 9, avg: 28.852941176470587, max: 91)
#
# Run: 35, exploration: 0.01, score: 71
# Scores: (min: 9, avg: 30.057142857142857, max: 91)
#
# Run: 36, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 29.77777777777778, max: 91)
#
# Run: 37, exploration: 0.01, score: 33
# Scores: (min: 9, avg: 29.864864864864863, max: 91)
#
# Run: 38, exploration: 0.01, score: 297
# Scores: (min: 9, avg: 36.89473684210526, max: 297)
#
# Run: 39, exploration: 0.01, score: 51
# Scores: (min: 9, avg: 37.256410256410255, max: 297)
#
# Run: 40, exploration: 0.01, score: 33
# Scores: (min: 9, avg: 37.15, max: 297)
#
# Run: 41, exploration: 0.01, score: 117
# Scores: (min: 9, avg: 39.09756097560975, max: 297)
#
# Run: 42, exploration: 0.01, score: 108
# Scores: (min: 9, avg: 40.73809523809524, max: 297)
#
# Run: 43, exploration: 0.01, score: 50
# Scores: (min: 9, avg: 40.95348837209303, max: 297)
#
# Run: 44, exploration: 0.01, score: 98
# Scores: (min: 9, avg: 42.25, max: 297)
#
# Run: 45, exploration: 0.01, score: 55
# Scores: (min: 9, avg: 42.53333333333333, max: 297)
#
# Run: 46, exploration: 0.01, score: 69
# Scores: (min: 9, avg: 43.108695652173914, max: 297)
#
# Run: 47, exploration: 0.01, score: 47
# Scores: (min: 9, avg: 43.191489361702125, max: 297)
#
# Run: 48, exploration: 0.01, score: 77
# Scores: (min: 9, avg: 43.895833333333336, max: 297)
#
# Run: 49, exploration: 0.01, score: 72
# Scores: (min: 9, avg: 44.46938775510204, max: 297)
#
# Run: 50, exploration: 0.01, score: 169
# Scores: (min: 9, avg: 46.96, max: 297)
#
# Run: 51, exploration: 0.01, score: 146
# Scores: (min: 9, avg: 48.90196078431372, max: 297)
#
# Run: 52, exploration: 0.01, score: 142
# Scores: (min: 9, avg: 50.69230769230769, max: 297)
#
# Run: 53, exploration: 0.01, score: 146
# Scores: (min: 9, avg: 52.490566037735846, max: 297)
#
# Run: 54, exploration: 0.01, score: 138
# Scores: (min: 9, avg: 54.074074074074076, max: 297)
#
# Run: 55, exploration: 0.01, score: 193
# Scores: (min: 9, avg: 56.6, max: 297)
#
# Run: 56, exploration: 0.01, score: 169
# Scores: (min: 9, avg: 58.607142857142854, max: 297)
#
# Run: 57, exploration: 0.01, score: 169
# Scores: (min: 9, avg: 60.54385964912281, max: 297)
#
# Run: 58, exploration: 0.01, score: 351
# Scores: (min: 9, avg: 65.55172413793103, max: 351)
#
# Run: 59, exploration: 0.01, score: 193
# Scores: (min: 9, avg: 67.71186440677967, max: 351)
#
# Run: 60, exploration: 0.01, score: 232
# Scores: (min: 9, avg: 70.45, max: 351)
#
# Run: 61, exploration: 0.01, score: 173
# Scores: (min: 9, avg: 72.1311475409836, max: 351)
#
# Run: 62, exploration: 0.01, score: 52
# Scores: (min: 9, avg: 71.80645161290323, max: 351)
#
# Run: 63, exploration: 0.01, score: 46
# Scores: (min: 9, avg: 71.39682539682539, max: 351)
#
# Run: 64, exploration: 0.01, score: 29
# Scores: (min: 9, avg: 70.734375, max: 351)
#
# Run: 65, exploration: 0.01, score: 184
# Scores: (min: 9, avg: 72.47692307692307, max: 351)
#
# Run: 66, exploration: 0.01, score: 85
# Scores: (min: 9, avg: 72.66666666666667, max: 351)
#
# Run: 67, exploration: 0.01, score: 190
# Scores: (min: 9, avg: 74.41791044776119, max: 351)
#
# Run: 68, exploration: 0.01, score: 277
# Scores: (min: 9, avg: 77.3970588235294, max: 351)
#
# Run: 69, exploration: 0.01, score: 199
# Scores: (min: 9, avg: 79.15942028985508, max: 351)
#
# Run: 70, exploration: 0.01, score: 235
# Scores: (min: 9, avg: 81.38571428571429, max: 351)
#
# Run: 71, exploration: 0.01, score: 201
# Scores: (min: 9, avg: 83.07042253521126, max: 351)
#
# Run: 72, exploration: 0.01, score: 227
# Scores: (min: 9, avg: 85.06944444444444, max: 351)
#
# Run: 73, exploration: 0.01, score: 166
# Scores: (min: 9, avg: 86.17808219178082, max: 351)
#
# Run: 74, exploration: 0.01, score: 187
# Scores: (min: 9, avg: 87.54054054054055, max: 351)
#
# Run: 75, exploration: 0.01, score: 230
# Scores: (min: 9, avg: 89.44, max: 351)
#
# Run: 76, exploration: 0.01, score: 194
# Scores: (min: 9, avg: 90.8157894736842, max: 351)
#
# Run: 77, exploration: 0.01, score: 179
# Scores: (min: 9, avg: 91.96103896103897, max: 351)
#
# Run: 78, exploration: 0.01, score: 347
# Scores: (min: 9, avg: 95.23076923076923, max: 351)
#
# Run: 79, exploration: 0.01, score: 196
# Scores: (min: 9, avg: 96.50632911392405, max: 351)
#
# Run: 80, exploration: 0.01, score: 42
# Scores: (min: 9, avg: 95.825, max: 351)
#
# Run: 81, exploration: 0.01, score: 163
# Scores: (min: 9, avg: 96.65432098765432, max: 351)
#
# Run: 82, exploration: 0.01, score: 243
# Scores: (min: 9, avg: 98.4390243902439, max: 351)
#
# Run: 83, exploration: 0.01, score: 176
# Scores: (min: 9, avg: 99.37349397590361, max: 351)
#
# Run: 84, exploration: 0.01, score: 62
# Scores: (min: 9, avg: 98.92857142857143, max: 351)
#
# Run: 85, exploration: 0.01, score: 154
# Scores: (min: 9, avg: 99.5764705882353, max: 351)
#
# Run: 86, exploration: 0.01, score: 141
# Scores: (min: 9, avg: 100.05813953488372, max: 351)
#
# Run: 87, exploration: 0.01, score: 245
# Scores: (min: 9, avg: 101.72413793103448, max: 351)
#
# Run: 88, exploration: 0.01, score: 173
# Scores: (min: 9, avg: 102.5340909090909, max: 351)
#
# Run: 89, exploration: 0.01, score: 190
# Scores: (min: 9, avg: 103.51685393258427, max: 351)
# Run: 90, exploration: 0.01, score: 35
# Scores: (min: 9, avg: 102.75555555555556, max: 351)
#
# Run: 91, exploration: 0.01, score: 253
# Scores: (min: 9, avg: 104.4065934065934, max: 351)
#
# Run: 92, exploration: 0.01, score: 222
# Scores: (min: 9, avg: 105.68478260869566, max: 351)
#
# Run: 93, exploration: 0.01, score: 176
# Scores: (min: 9, avg: 106.44086021505376, max: 351)
#
# Run: 94, exploration: 0.01, score: 246
# Scores: (min: 9, avg: 107.92553191489361, max: 351)
#
# Run: 95, exploration: 0.01, score: 200
# Scores: (min: 9, avg: 108.89473684210526, max: 351)
#
# Run: 96, exploration: 0.01, score: 143
# Scores: (min: 9, avg: 109.25, max: 351)
#
# Run: 97, exploration: 0.01, score: 42
# Scores: (min: 9, avg: 108.55670103092784, max: 351)
#
# Run: 98, exploration: 0.01, score: 53
# Scores: (min: 9, avg: 107.98979591836735, max: 351)
#
# Run: 99, exploration: 0.01, score: 144
# Scores: (min: 9, avg: 108.35353535353535, max: 351)
#
# Run: 100, exploration: 0.01, score: 67
# Scores: (min: 9, avg: 107.94, max: 351)
#
# Run: 101, exploration: 0.01, score: 159
# Scores: (min: 9, avg: 109.34, max: 351)
#
# Run: 102, exploration: 0.01, score: 205
# Scores: (min: 9, avg: 111.28, max: 351)
#
# Run: 103, exploration: 0.01, score: 146
# Scores: (min: 9, avg: 112.54, max: 351)
#
# Run: 104, exploration: 0.01, score: 108
# Scores: (min: 9, avg: 113.52, max: 351)
#
# Run: 105, exploration: 0.01, score: 162
# Scores: (min: 9, avg: 114.97, max: 351)
#
# Run: 106, exploration: 0.01, score: 24
# Scores: (min: 9, avg: 114.3, max: 351)
#
# Run: 107, exploration: 0.01, score: 116
# Scores: (min: 9, avg: 115.18, max: 351)
#
# Run: 108, exploration: 0.01, score: 47
# Scores: (min: 9, avg: 115.46, max: 351)
#
# Run: 109, exploration: 0.01, score: 24
# Scores: (min: 9, avg: 115.53, max: 351)
#
# Run: 110, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 115.07, max: 351)
#
# Run: 111, exploration: 0.01, score: 187
# Scores: (min: 9, avg: 116.76, max: 351)
#
# Run: 112, exploration: 0.01, score: 37
# Scores: (min: 9, avg: 116.82, max: 351)
#
# Run: 113, exploration: 0.01, score: 134
# Scores: (min: 9, avg: 117.82, max: 351)
#
# Run: 114, exploration: 0.01, score: 144
# Scores: (min: 9, avg: 119.09, max: 351)
#
# Run: 115, exploration: 0.01, score: 47
# Scores: (min: 9, avg: 119.42, max: 351)
#
# Run: 116, exploration: 0.01, score: 130
# Scores: (min: 9, avg: 120.48, max: 351)
#
# Run: 117, exploration: 0.01, score: 140
# Scores: (min: 9, avg: 121.3, max: 351)
#
# Run: 118, exploration: 0.01, score: 176
# Scores: (min: 9, avg: 122.94, max: 351)
#
# Run: 119, exploration: 0.01, score: 61
# Scores: (min: 9, avg: 123.35, max: 351)
#
# Run: 120, exploration: 0.01, score: 204
# Scores: (min: 9, avg: 124.65, max: 351)
#
# Run: 121, exploration: 0.01, score: 420
# Scores: (min: 9, avg: 128.58, max: 420)
#
# Run: 122, exploration: 0.01, score: 204
# Scores: (min: 9, avg: 130.45, max: 420)
#
# Run: 123, exploration: 0.01, score: 121
# Scores: (min: 9, avg: 131.55, max: 420)
#
# Run: 124, exploration: 0.01, score: 138
# Scores: (min: 9, avg: 132.77, max: 420)
#
# Run: 125, exploration: 0.01, score: 105
# Scores: (min: 10, avg: 133.73, max: 420)
#
# Run: 126, exploration: 0.01, score: 19
# Scores: (min: 10, avg: 133.65, max: 420)
#
# Run: 127, exploration: 0.01, score: 97
# Scores: (min: 10, avg: 134.1, max: 420)
#
# Run: 128, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 133.7, max: 420)
#
# Run: 129, exploration: 0.01, score: 28
# Scores: (min: 10, avg: 133.82, max: 420)
#
# Run: 130, exploration: 0.01, score: 138
# Scores: (min: 10, avg: 134.96, max: 420)
#
# Run: 131, exploration: 0.01, score: 60
# Scores: (min: 10, avg: 135.15, max: 420)
#
# Run: 132, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 134.97, max: 420)
#
# Run: 133, exploration: 0.01, score: 191
# Scores: (min: 10, avg: 136.57, max: 420)
#
# Run: 134, exploration: 0.01, score: 56
# Scores: (min: 10, avg: 136.75, max: 420)
#
# Run: 135, exploration: 0.01, score: 19
# Scores: (min: 10, avg: 136.23, max: 420)
#
# Run: 136, exploration: 0.01, score: 141
# Scores: (min: 10, avg: 137.44, max: 420)
#
# Run: 137, exploration: 0.01, score: 68
# Scores: (min: 10, avg: 137.79, max: 420)
#
# Run: 138, exploration: 0.01, score: 261
# Scores: (min: 10, avg: 137.43, max: 420)
#
# Run: 139, exploration: 0.01, score: 193
# Scores: (min: 10, avg: 138.85, max: 420)
#
# Run: 140, exploration: 0.01, score: 186
# Scores: (min: 10, avg: 140.38, max: 420)
#
# Run: 141, exploration: 0.01, score: 45
# Scores: (min: 10, avg: 139.66, max: 420)
#
# Run: 142, exploration: 0.01, score: 159
# Scores: (min: 10, avg: 140.17, max: 420)
#
# Run: 143, exploration: 0.01, score: 99
# Scores: (min: 10, avg: 140.66, max: 420)
#
# Run: 144, exploration: 0.01, score: 165
# Scores: (min: 10, avg: 141.33, max: 420)
#
# Run: 145, exploration: 0.01, score: 108
# Scores: (min: 10, avg: 141.86, max: 420)
#
# Run: 146, exploration: 0.01, score: 71
# Scores: (min: 10, avg: 141.88, max: 420)
#
# Run: 147, exploration: 0.01, score: 155
# Scores: (min: 10, avg: 142.96, max: 420)
#
# Run: 148, exploration: 0.01, score: 157
# Scores: (min: 10, avg: 143.76, max: 420)
#
# Run: 149, exploration: 0.01, score: 143
# Scores: (min: 10, avg: 144.47, max: 420)
#
# Run: 150, exploration: 0.01, score: 100
# Scores: (min: 10, avg: 143.78, max: 420)
#
# Run: 151, exploration: 0.01, score: 152
# Scores: (min: 10, avg: 143.84, max: 420)
#
# Run: 152, exploration: 0.01, score: 160
# Scores: (min: 10, avg: 144.02, max: 420)
#
# Run: 153, exploration: 0.01, score: 140
# Scores: (min: 10, avg: 143.96, max: 420)
#
# Run: 154, exploration: 0.01, score: 181
# Scores: (min: 10, avg: 144.39, max: 420)
#
# Run: 155, exploration: 0.01, score: 85
# Scores: (min: 10, avg: 143.31, max: 420)
#
# Run: 156, exploration: 0.01, score: 39
# Scores: (min: 10, avg: 142.01, max: 420)
#
# Run: 157, exploration: 0.01, score: 56
# Scores: (min: 10, avg: 140.88, max: 420)
#
# Run: 158, exploration: 0.01, score: 252
# Scores: (min: 10, avg: 139.89, max: 420)
#
# Run: 159, exploration: 0.01, score: 231
# Scores: (min: 10, avg: 140.27, max: 420)
#
# Run: 160, exploration: 0.01, score: 100
# Scores: (min: 10, avg: 138.95, max: 420)
#
# Run: 161, exploration: 0.01, score: 60
# Scores: (min: 10, avg: 137.82, max: 420)
#
# Run: 162, exploration: 0.01, score: 69
# Scores: (min: 10, avg: 137.99, max: 420)
#
# Run: 163, exploration: 0.01, score: 30
# Scores: (min: 10, avg: 137.83, max: 420)
#
# Run: 164, exploration: 0.01, score: 65
# Scores: (min: 10, avg: 138.19, max: 420)
#
# Run: 165, exploration: 0.01, score: 25
# Scores: (min: 10, avg: 136.6, max: 420)
#
# Run: 166, exploration: 0.01, score: 144
# Scores: (min: 10, avg: 137.19, max: 420)
#
# Run: 167, exploration: 0.01, score: 90
# Scores: (min: 10, avg: 136.19, max: 420)
#
# Run: 168, exploration: 0.01, score: 131
# Scores: (min: 10, avg: 134.73, max: 420)
#
# Run: 169, exploration: 0.01, score: 33
# Scores: (min: 10, avg: 133.07, max: 420)
#
# Run: 170, exploration: 0.01, score: 66
# Scores: (min: 10, avg: 131.38, max: 420)
#
# Run: 171, exploration: 0.01, score: 110
# Scores: (min: 10, avg: 130.47, max: 420)
#
# Run: 172, exploration: 0.01, score: 29
# Scores: (min: 10, avg: 128.49, max: 420)
#
# Run: 173, exploration: 0.01, score: 27
# Scores: (min: 10, avg: 127.1, max: 420)
#
# Run: 174, exploration: 0.01, score: 38
# Scores: (min: 10, avg: 125.61, max: 420)
#
# Run: 175, exploration: 0.01, score: 24
# Scores: (min: 10, avg: 123.55, max: 420)
#
# Run: 176, exploration: 0.01, score: 76
# Scores: (min: 10, avg: 122.37, max: 420)
#
# Run: 177, exploration: 0.01, score: 17
# Scores: (min: 10, avg: 120.75, max: 420)
#
# Run: 178, exploration: 0.01, score: 18
# Scores: (min: 10, avg: 117.46, max: 420)
#
# Run: 179, exploration: 0.01, score: 34
# Scores: (min: 10, avg: 115.84, max: 420)
#
# Run: 180, exploration: 0.01, score: 26
# Scores: (min: 10, avg: 115.68, max: 420)
#
# Run: 181, exploration: 0.01, score: 104
# Scores: (min: 10, avg: 115.09, max: 420)
#
# Run: 182, exploration: 0.01, score: 79
# Scores: (min: 10, avg: 113.45, max: 420)
#
# Run: 183, exploration: 0.01, score: 210
# Scores: (min: 10, avg: 113.79, max: 420)
#
# Run: 184, exploration: 0.01, score: 155
# Scores: (min: 10, avg: 114.72, max: 420)
#
# Run: 185, exploration: 0.01, score: 27
# Scores: (min: 10, avg: 113.45, max: 420)
#
# Run: 186, exploration: 0.01, score: 33
# Scores: (min: 10, avg: 112.37, max: 420)
#
# Run: 187, exploration: 0.01, score: 44
# Scores: (min: 10, avg: 110.36, max: 420)
#
# Run: 188, exploration: 0.01, score: 36
# Scores: (min: 10, avg: 108.99, max: 420)
#
# Run: 189, exploration: 0.01, score: 53
# Scores: (min: 10, avg: 107.62, max: 420)
# Run: 190, exploration: 0.01, score: 162
# Scores: (min: 10, avg: 108.89, max: 420)
#
# Run: 191, exploration: 0.01, score: 125
# Scores: (min: 10, avg: 107.61, max: 420)
#
# Run: 192, exploration: 0.01, score: 135
# Scores: (min: 10, avg: 106.74, max: 420)
#
# Run: 193, exploration: 0.01, score: 146
# Scores: (min: 10, avg: 106.44, max: 420)
#
# Run: 194, exploration: 0.01, score: 29
# Scores: (min: 10, avg: 104.27, max: 420)
#
# Run: 195, exploration: 0.01, score: 79
# Scores: (min: 10, avg: 103.06, max: 420)
#
# Run: 196, exploration: 0.01, score: 14
# Scores: (min: 10, avg: 101.77, max: 420)
#
# Run: 197, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 101.45, max: 420)
#
# Run: 198, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 101.03, max: 420)
#
# Run: 199, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 99.7, max: 420)
#
# Run: 200, exploration: 0.01, score: 57
# Scores: (min: 10, avg: 99.6, max: 420)
#
# Run: 201, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 98.11, max: 420)
#
# Run: 202, exploration: 0.01, score: 124
# Scores: (min: 10, avg: 97.3, max: 420)
#
# Run: 203, exploration: 0.01, score: 65
# Scores: (min: 10, avg: 96.49, max: 420)
#
# Run: 204, exploration: 0.01, score: 64
# Scores: (min: 10, avg: 96.05, max: 420)
#
# Run: 205, exploration: 0.01, score: 118
# Scores: (min: 10, avg: 95.61, max: 420)
#
# Run: 206, exploration: 0.01, score: 107
# Scores: (min: 10, avg: 96.44, max: 420)
#
# Run: 207, exploration: 0.01, score: 38
# Scores: (min: 10, avg: 95.66, max: 420)
#
# Run: 208, exploration: 0.01, score: 24
# Scores: (min: 10, avg: 95.43, max: 420)
#
# Run: 209, exploration: 0.01, score: 57
# Scores: (min: 10, avg: 95.76, max: 420)
#
# Run: 210, exploration: 0.01, score: 24
# Scores: (min: 10, avg: 95.9, max: 420)
#
# Run: 211, exploration: 0.01, score: 47
# Scores: (min: 10, avg: 94.5, max: 420)
#
# Run: 212, exploration: 0.01, score: 72
# Scores: (min: 10, avg: 94.85, max: 420)
#
# Run: 213, exploration: 0.01, score: 32
# Scores: (min: 10, avg: 93.83, max: 420)
#
# Run: 214, exploration: 0.01, score: 42
# Scores: (min: 10, avg: 92.81, max: 420)
#
# Run: 215, exploration: 0.01, score: 154
# Scores: (min: 10, avg: 93.88, max: 420)
#
# Run: 216, exploration: 0.01, score: 191
# Scores: (min: 10, avg: 94.49, max: 420)
#
# Run: 217, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 93.2, max: 420)
#
# Run: 218, exploration: 0.01, score: 121
# Scores: (min: 10, avg: 92.65, max: 420)
#
# Run: 219, exploration: 0.01, score: 27
# Scores: (min: 10, avg: 92.31, max: 420)
#
# Run: 220, exploration: 0.01, score: 16
# Scores: (min: 10, avg: 90.43, max: 420)
#
# Run: 221, exploration: 0.01, score: 117
# Scores: (min: 10, avg: 87.4, max: 261)
#
# Run: 222, exploration: 0.01, score: 60
# Scores: (min: 10, avg: 85.96, max: 261)
#
# Run: 223, exploration: 0.01, score: 186
# Scores: (min: 10, avg: 86.61, max: 261)
#
# Run: 224, exploration: 0.01, score: 22
# Scores: (min: 10, avg: 85.45, max: 261)
#
# Run: 225, exploration: 0.01, score: 63
# Scores: (min: 10, avg: 85.03, max: 261)
#
# Run: 226, exploration: 0.01, score: 48
# Scores: (min: 10, avg: 85.32, max: 261)
#
# Run: 227, exploration: 0.01, score: 54
# Scores: (min: 10, avg: 84.89, max: 261)
#
# Run: 228, exploration: 0.01, score: 31
# Scores: (min: 10, avg: 85.07, max: 261)
#
# Run: 229, exploration: 0.01, score: 29
# Scores: (min: 10, avg: 85.08, max: 261)
#
# Run: 230, exploration: 0.01, score: 85
# Scores: (min: 10, avg: 84.55, max: 261)
#
# Run: 231, exploration: 0.01, score: 33
# Scores: (min: 10, avg: 84.28, max: 261)
#
# Run: 232, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 84.29, max: 261)
#
# Run: 233, exploration: 0.01, score: 59
# Scores: (min: 10, avg: 82.97, max: 261)
#
# Run: 234, exploration: 0.01, score: 67
# Scores: (min: 10, avg: 83.08, max: 261)
#
# Run: 235, exploration: 0.01, score: 77
# Scores: (min: 10, avg: 83.66, max: 261)
#
# Run: 236, exploration: 0.01, score: 24
# Scores: (min: 10, avg: 82.49, max: 261)
#
# Run: 237, exploration: 0.01, score: 113
# Scores: (min: 10, avg: 82.94, max: 261)
#
# Run: 238, exploration: 0.01, score: 17
# Scores: (min: 10, avg: 80.5, max: 252)
#
# Run: 239, exploration: 0.01, score: 184
# Scores: (min: 10, avg: 80.41, max: 252)
#
# Run: 240, exploration: 0.01, score: 158
# Scores: (min: 10, avg: 80.13, max: 252)
#
# Run: 241, exploration: 0.01, score: 134
# Scores: (min: 10, avg: 81.02, max: 252)
#
# Run: 242, exploration: 0.01, score: 37
# Scores: (min: 10, avg: 79.8, max: 252)
#
# Run: 243, exploration: 0.01, score: 52
# Scores: (min: 10, avg: 79.33, max: 252)
#
# Run: 244, exploration: 0.01, score: 90
# Scores: (min: 10, avg: 78.58, max: 252)
#
# Run: 245, exploration: 0.01, score: 39
# Scores: (min: 10, avg: 77.89, max: 252)
#
# Run: 246, exploration: 0.01, score: 81
# Scores: (min: 10, avg: 77.99, max: 252)
#
# Run: 247, exploration: 0.01, score: 151
# Scores: (min: 10, avg: 77.95, max: 252)
#
# Run: 248, exploration: 0.01, score: 39
# Scores: (min: 10, avg: 76.77, max: 252)
#
# Run: 249, exploration: 0.01, score: 78
# Scores: (min: 10, avg: 76.12, max: 252)
#
# Run: 250, exploration: 0.01, score: 26
# Scores: (min: 10, avg: 75.38, max: 252)
#
# Run: 251, exploration: 0.01, score: 134
# Scores: (min: 10, avg: 75.2, max: 252)
#
# Run: 252, exploration: 0.01, score: 36
# Scores: (min: 10, avg: 73.96, max: 252)
#
# Run: 253, exploration: 0.01, score: 31
# Scores: (min: 10, avg: 72.87, max: 252)
#
# Run: 254, exploration: 0.01, score: 120
# Scores: (min: 10, avg: 72.26, max: 252)
#
# Run: 255, exploration: 0.01, score: 30
# Scores: (min: 10, avg: 71.71, max: 252)
#
# Run: 256, exploration: 0.01, score: 131
# Scores: (min: 10, avg: 72.63, max: 252)
#
# Run: 257, exploration: 0.01, score: 29
# Scores: (min: 10, avg: 72.36, max: 252)
#
# Run: 258, exploration: 0.01, score: 114
# Scores: (min: 10, avg: 70.98, max: 231)
#
# Run: 259, exploration: 0.01, score: 32
# Scores: (min: 10, avg: 68.99, max: 210)
#
# Run: 260, exploration: 0.01, score: 104
# Scores: (min: 10, avg: 69.03, max: 210)
#
# Run: 261, exploration: 0.01, score: 104
# Scores: (min: 10, avg: 69.47, max: 210)
#
# Run: 262, exploration: 0.01, score: 82
# Scores: (min: 10, avg: 69.6, max: 210)
#
# Run: 263, exploration: 0.01, score: 226
# Scores: (min: 10, avg: 71.56, max: 226)
#
# Run: 264, exploration: 0.01, score: 155
# Scores: (min: 10, avg: 72.46, max: 226)
#
# Run: 265, exploration: 0.01, score: 77
# Scores: (min: 10, avg: 72.98, max: 226)
#
# Run: 266, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 71.64, max: 226)
#
# Run: 267, exploration: 0.01, score: 50
# Scores: (min: 10, avg: 71.24, max: 226)
#
# Run: 268, exploration: 0.01, score: 40
# Scores: (min: 10, avg: 70.33, max: 226)
#
# Run: 269, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 70.12, max: 226)
#
# Run: 270, exploration: 0.01, score: 108
# Scores: (min: 10, avg: 70.54, max: 226)
#
# Run: 271, exploration: 0.01, score: 107
# Scores: (min: 10, avg: 70.51, max: 226)
#
# Run: 272, exploration: 0.01, score: 105
# Scores: (min: 10, avg: 71.27, max: 226)
#
# Run: 273, exploration: 0.01, score: 24
# Scores: (min: 10, avg: 71.24, max: 226)
#
# Run: 274, exploration: 0.01, score: 93
# Scores: (min: 10, avg: 71.79, max: 226)
#
# Run: 275, exploration: 0.01, score: 98
# Scores: (min: 10, avg: 72.53, max: 226)
#
# Run: 276, exploration: 0.01, score: 80
# Scores: (min: 10, avg: 72.57, max: 226)
#
# Run: 277, exploration: 0.01, score: 54
# Scores: (min: 10, avg: 72.94, max: 226)
#
# Run: 278, exploration: 0.01, score: 132
# Scores: (min: 10, avg: 74.08, max: 226)
#
# Run: 279, exploration: 0.01, score: 39
# Scores: (min: 10, avg: 74.13, max: 226)
#
# Run: 280, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 73.97, max: 226)
#
# Run: 281, exploration: 0.01, score: 105
# Scores: (min: 10, avg: 73.98, max: 226)
#
# Run: 282, exploration: 0.01, score: 38
# Scores: (min: 10, avg: 73.57, max: 226)
#
# Run: 283, exploration: 0.01, score: 73
# Scores: (min: 10, avg: 72.2, max: 226)
#
# Run: 284, exploration: 0.01, score: 87
# Scores: (min: 10, avg: 71.52, max: 226)
#
# Run: 285, exploration: 0.01, score: 67
# Scores: (min: 10, avg: 71.92, max: 226)
#
# Run: 286, exploration: 0.01, score: 30
# Scores: (min: 10, avg: 71.89, max: 226)
#
# Run: 287, exploration: 0.01, score: 29
# Scores: (min: 10, avg: 71.74, max: 226)
#
# Run: 288, exploration: 0.01, score: 23
# Scores: (min: 10, avg: 71.61, max: 226)
#
# Run: 289, exploration: 0.01, score: 14
# Scores: (min: 10, avg: 71.22, max: 226)
#
# Run: 290, exploration: 0.01, score: 141
# Scores: (min: 10, avg: 71.01, max: 226)
#
# Run: 291, exploration: 0.01, score: 101
# Scores: (min: 10, avg: 70.77, max: 226)
#
# Run: 292, exploration: 0.01, score: 77
# Scores: (min: 10, avg: 70.19, max: 226)
# Run: 293, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 68.85, max: 226)
#
# Run: 294, exploration: 0.01, score: 98
# Scores: (min: 10, avg: 69.54, max: 226)
#
# Run: 295, exploration: 0.01, score: 51
# Scores: (min: 10, avg: 69.26, max: 226)
#
# Run: 296, exploration: 0.01, score: 37
# Scores: (min: 10, avg: 69.49, max: 226)
#
# Run: 297, exploration: 0.01, score: 221
# Scores: (min: 10, avg: 71.6, max: 226)
#
# Run: 298, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 71.61, max: 226)
#
# Run: 299, exploration: 0.01, score: 16
# Scores: (min: 10, avg: 71.66, max: 226)
#
# Run: 300, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 71.19, max: 226)
#
# Run: 301, exploration: 0.01, score: 57
# Scores: (min: 10, avg: 71.66, max: 226)
#
# Run: 302, exploration: 0.01, score: 26
# Scores: (min: 10, avg: 70.68, max: 226)
#
# Run: 303, exploration: 0.01, score: 27
# Scores: (min: 10, avg: 70.3, max: 226)
#
# Run: 304, exploration: 0.01, score: 32
# Scores: (min: 10, avg: 69.98, max: 226)
#
# Run: 305, exploration: 0.01, score: 150
# Scores: (min: 10, avg: 70.3, max: 226)
#
# Run: 306, exploration: 0.01, score: 101
# Scores: (min: 10, avg: 70.24, max: 226)
#
# Run: 307, exploration: 0.01, score: 57
# Scores: (min: 10, avg: 70.43, max: 226)
#
# Run: 308, exploration: 0.01, score: 94
# Scores: (min: 10, avg: 71.13, max: 226)
#
# Run: 309, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 70.69, max: 226)
#
# Run: 310, exploration: 0.01, score: 103
# Scores: (min: 10, avg: 71.48, max: 226)
#
# Run: 311, exploration: 0.01, score: 28
# Scores: (min: 10, avg: 71.29, max: 226)
#
# Run: 312, exploration: 0.01, score: 39
# Scores: (min: 10, avg: 70.96, max: 226)
#
# Run: 313, exploration: 0.01, score: 186
# Scores: (min: 10, avg: 72.5, max: 226)
#
# Run: 314, exploration: 0.01, score: 88
# Scores: (min: 10, avg: 72.96, max: 226)
#
# Run: 315, exploration: 0.01, score: 26
# Scores: (min: 10, avg: 71.68, max: 226)
#
# Run: 316, exploration: 0.01, score: 96
# Scores: (min: 10, avg: 70.73, max: 226)
#
# Run: 317, exploration: 0.01, score: 110
# Scores: (min: 10, avg: 71.72, max: 226)
#
# Run: 318, exploration: 0.01, score: 141
# Scores: (min: 10, avg: 71.92, max: 226)
#
# Run: 319, exploration: 0.01, score: 114
# Scores: (min: 10, avg: 72.79, max: 226)
#
# Run: 320, exploration: 0.01, score: 101
# Scores: (min: 10, avg: 73.64, max: 226)
#
# Run: 321, exploration: 0.01, score: 134
# Scores: (min: 10, avg: 73.81, max: 226)
#
# Run: 322, exploration: 0.01, score: 136
# Scores: (min: 10, avg: 74.57, max: 226)
#
# Run: 323, exploration: 0.01, score: 194
# Scores: (min: 10, avg: 74.65, max: 226)
#
# Run: 324, exploration: 0.01, score: 65
# Scores: (min: 10, avg: 75.08, max: 226)
#
# Run: 325, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 74.57, max: 226)
#
# Run: 326, exploration: 0.01, score: 31
# Scores: (min: 10, avg: 74.4, max: 226)
#
# Run: 327, exploration: 0.01, score: 39
# Scores: (min: 10, avg: 74.25, max: 226)
#
# Run: 328, exploration: 0.01, score: 122
# Scores: (min: 10, avg: 75.16, max: 226)
#
# Run: 329, exploration: 0.01, score: 160
# Scores: (min: 10, avg: 76.47, max: 226)
#
# Run: 330, exploration: 0.01, score: 130
# Scores: (min: 10, avg: 76.92, max: 226)
#
# Run: 331, exploration: 0.01, score: 191
# Scores: (min: 10, avg: 78.5, max: 226)
#
# Run: 332, exploration: 0.01, score: 21
# Scores: (min: 10, avg: 78.59, max: 226)
#
# Run: 333, exploration: 0.01, score: 25
# Scores: (min: 10, avg: 78.25, max: 226)
#
# Run: 334, exploration: 0.01, score: 199
# Scores: (min: 10, avg: 79.57, max: 226)
#
# Run: 335, exploration: 0.01, score: 130
# Scores: (min: 10, avg: 80.1, max: 226)
#
# Run: 336, exploration: 0.01, score: 50
# Scores: (min: 10, avg: 80.36, max: 226)
#
# Run: 337, exploration: 0.01, score: 101
# Scores: (min: 10, avg: 80.24, max: 226)
#
# Run: 338, exploration: 0.01, score: 79
# Scores: (min: 10, avg: 80.86, max: 226)
#
# Run: 339, exploration: 0.01, score: 116
# Scores: (min: 10, avg: 80.18, max: 226)
#
# Run: 340, exploration: 0.01, score: 73
# Scores: (min: 10, avg: 79.33, max: 226)
#
# Run: 341, exploration: 0.01, score: 22
# Scores: (min: 10, avg: 78.21, max: 226)
#
# Run: 342, exploration: 0.01, score: 18
# Scores: (min: 10, avg: 78.02, max: 226)
#
# Run: 343, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 77.61, max: 226)
#
# Run: 344, exploration: 0.01, score: 35
# Scores: (min: 10, avg: 77.06, max: 226)
#
# Run: 345, exploration: 0.01, score: 57
# Scores: (min: 10, avg: 77.24, max: 226)
#
# Run: 346, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 76.54, max: 226)
#
# Run: 347, exploration: 0.01, score: 27
# Scores: (min: 10, avg: 75.3, max: 226)
#
# Run: 348, exploration: 0.01, score: 44
# Scores: (min: 10, avg: 75.35, max: 226)
#
# Run: 349, exploration: 0.01, score: 148
# Scores: (min: 10, avg: 76.05, max: 226)
#
# Run: 350, exploration: 0.01, score: 165
# Scores: (min: 10, avg: 77.44, max: 226)
#
# Run: 351, exploration: 0.01, score: 140
# Scores: (min: 10, avg: 77.5, max: 226)
#
# Run: 352, exploration: 0.01, score: 92
# Scores: (min: 10, avg: 78.06, max: 226)
#
# Run: 353, exploration: 0.01, score: 48
# Scores: (min: 10, avg: 78.23, max: 226)
#
# Run: 354, exploration: 0.01, score: 98
# Scores: (min: 10, avg: 78.01, max: 226)
#
# Run: 355, exploration: 0.01, score: 28
# Scores: (min: 10, avg: 77.99, max: 226)
#
# Run: 356, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 76.8, max: 226)
#
# Run: 357, exploration: 0.01, score: 179
# Scores: (min: 10, avg: 78.3, max: 226)
#
# Run: 358, exploration: 0.01, score: 73
# Scores: (min: 10, avg: 77.89, max: 226)
#
# Run: 359, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 77.7, max: 226)
#
# Run: 360, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 76.79, max: 226)
#
# Run: 361, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 75.86, max: 226)
#
# Run: 362, exploration: 0.01, score: 132
# Scores: (min: 10, avg: 76.36, max: 226)
#
# Run: 363, exploration: 0.01, score: 51
# Scores: (min: 10, avg: 74.61, max: 221)
#
# Run: 364, exploration: 0.01, score: 81
# Scores: (min: 10, avg: 73.87, max: 221)
#
# Run: 365, exploration: 0.01, score: 102
# Scores: (min: 10, avg: 74.12, max: 221)
#
# Run: 366, exploration: 0.01, score: 18
# Scores: (min: 10, avg: 74.2, max: 221)
#
# Run: 367, exploration: 0.01, score: 138
# Scores: (min: 10, avg: 75.08, max: 221)
#
# Run: 368, exploration: 0.01, score: 133
# Scores: (min: 10, avg: 76.01, max: 221)
#
# Run: 369, exploration: 0.01, score: 31
# Scores: (min: 10, avg: 76.2, max: 221)
#
# Run: 370, exploration: 0.01, score: 41
# Scores: (min: 10, avg: 75.53, max: 221)
#
# Run: 371, exploration: 0.01, score: 47
# Scores: (min: 10, avg: 74.93, max: 221)
#
# Run: 372, exploration: 0.01, score: 42
# Scores: (min: 10, avg: 74.3, max: 221)
#
# Run: 373, exploration: 0.01, score: 47
# Scores: (min: 10, avg: 74.53, max: 221)
#
# Run: 374, exploration: 0.01, score: 39
# Scores: (min: 10, avg: 73.99, max: 221)
#
# Run: 375, exploration: 0.01, score: 40
# Scores: (min: 10, avg: 73.41, max: 221)
#
# Run: 376, exploration: 0.01, score: 70
# Scores: (min: 10, avg: 73.31, max: 221)
#
# Run: 377, exploration: 0.01, score: 112
# Scores: (min: 10, avg: 73.89, max: 221)
#
# Run: 378, exploration: 0.01, score: 52
# Scores: (min: 10, avg: 73.09, max: 221)
#
# Run: 379, exploration: 0.01, score: 123
# Scores: (min: 10, avg: 73.93, max: 221)
#
# Run: 380, exploration: 0.01, score: 165
# Scores: (min: 10, avg: 75.48, max: 221)
#
# Run: 381, exploration: 0.01, score: 20
# Scores: (min: 10, avg: 74.63, max: 221)
#
# Run: 382, exploration: 0.01, score: 53
# Scores: (min: 10, avg: 74.78, max: 221)
#
# Run: 383, exploration: 0.01, score: 69
# Scores: (min: 10, avg: 74.74, max: 221)
#
# Run: 384, exploration: 0.01, score: 33
# Scores: (min: 10, avg: 74.2, max: 221)
#
# Run: 385, exploration: 0.01, score: 15
# Scores: (min: 10, avg: 73.68, max: 221)
#
# Run: 386, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 73.49, max: 221)
#
# Run: 387, exploration: 0.01, score: 107
# Scores: (min: 10, avg: 74.27, max: 221)
#
# Run: 388, exploration: 0.01, score: 15
# Scores: (min: 10, avg: 74.19, max: 221)
#
# Run: 389, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 74.16, max: 221)
#
# Run: 390, exploration: 0.01, score: 46
# Scores: (min: 10, avg: 73.21, max: 221)
#
# Run: 391, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 72.32, max: 221)
#
# Run: 392, exploration: 0.01, score: 43
# Scores: (min: 10, avg: 71.98, max: 221)
#
# Run: 393, exploration: 0.01, score: 28
# Scores: (min: 10, avg: 72.14, max: 221)
#
# Run: 394, exploration: 0.01, score: 142
# Scores: (min: 10, avg: 72.58, max: 221)
#
# Run: 395, exploration: 0.01, score: 25
# Scores: (min: 10, avg: 72.32, max: 221)
# Run: 396, exploration: 0.01, score: 97
# Scores: (min: 10, avg: 72.92, max: 221)
#
# Run: 397, exploration: 0.01, score: 95
# Scores: (min: 10, avg: 71.66, max: 199)
#
# Run: 398, exploration: 0.01, score: 223
# Scores: (min: 10, avg: 73.77, max: 223)
#
# Run: 399, exploration: 0.01, score: 52
# Scores: (min: 10, avg: 74.13, max: 223)
#
# Run: 400, exploration: 0.01, score: 140
# Scores: (min: 11, avg: 75.43, max: 223)
#
# Run: 401, exploration: 0.01, score: 118
# Scores: (min: 11, avg: 76.04, max: 223)
#
# Run: 402, exploration: 0.01, score: 185
# Scores: (min: 11, avg: 77.63, max: 223)
#
# Run: 403, exploration: 0.01, score: 165
# Scores: (min: 11, avg: 79.01, max: 223)
#
# Run: 404, exploration: 0.01, score: 142
# Scores: (min: 11, avg: 80.11, max: 223)
#
# Run: 405, exploration: 0.01, score: 78
# Scores: (min: 11, avg: 79.39, max: 223)
#
# Run: 406, exploration: 0.01, score: 28
# Scores: (min: 11, avg: 78.66, max: 223)
#
# Run: 407, exploration: 0.01, score: 23
# Scores: (min: 11, avg: 78.32, max: 223)
#
# Run: 408, exploration: 0.01, score: 42
# Scores: (min: 11, avg: 77.8, max: 223)
#
# Run: 409, exploration: 0.01, score: 22
# Scores: (min: 11, avg: 77.89, max: 223)
#
# Run: 410, exploration: 0.01, score: 11
# Scores: (min: 11, avg: 76.97, max: 223)
#
# Run: 411, exploration: 0.01, score: 12
# Scores: (min: 11, avg: 76.81, max: 223)
#
# Run: 412, exploration: 0.01, score: 21
# Scores: (min: 11, avg: 76.63, max: 223)
#
# Run: 413, exploration: 0.01, score: 105
# Scores: (min: 11, avg: 75.82, max: 223)
#
# Run: 414, exploration: 0.01, score: 23
# Scores: (min: 11, avg: 75.17, max: 223)
#
# Run: 415, exploration: 0.01, score: 71
# Scores: (min: 11, avg: 75.62, max: 223)
#
# Run: 416, exploration: 0.01, score: 105
# Scores: (min: 11, avg: 75.71, max: 223)
#
# Run: 417, exploration: 0.01, score: 59
# Scores: (min: 11, avg: 75.2, max: 223)
#
# Run: 418, exploration: 0.01, score: 23
# Scores: (min: 11, avg: 74.02, max: 223)
#
# Run: 419, exploration: 0.01, score: 46
# Scores: (min: 11, avg: 73.34, max: 223)
#
# Run: 420, exploration: 0.01, score: 83
# Scores: (min: 11, avg: 73.16, max: 223)
#
# Run: 421, exploration: 0.01, score: 12
# Scores: (min: 11, avg: 71.94, max: 223)
#
# Run: 422, exploration: 0.01, score: 65
# Scores: (min: 11, avg: 71.23, max: 223)
#
# Run: 423, exploration: 0.01, score: 36
# Scores: (min: 11, avg: 69.65, max: 223)
#
# Run: 424, exploration: 0.01, score: 51
# Scores: (min: 11, avg: 69.51, max: 223)
#
# Run: 425, exploration: 0.01, score: 50
# Scores: (min: 11, avg: 69.89, max: 223)
#
# Run: 426, exploration: 0.01, score: 91
# Scores: (min: 11, avg: 70.49, max: 223)
#
# Run: 427, exploration: 0.01, score: 12
# Scores: (min: 11, avg: 70.22, max: 223)
#
# Run: 428, exploration: 0.01, score: 48
# Scores: (min: 11, avg: 69.48, max: 223)
#
# Run: 429, exploration: 0.01, score: 38
# Scores: (min: 11, avg: 68.26, max: 223)
#
# Run: 430, exploration: 0.01, score: 54
# Scores: (min: 11, avg: 67.5, max: 223)
#
# Run: 431, exploration: 0.01, score: 30
# Scores: (min: 11, avg: 65.89, max: 223)
#
# Run: 432, exploration: 0.01, score: 12
# Scores: (min: 11, avg: 65.8, max: 223)
#
# Run: 433, exploration: 0.01, score: 45
# Scores: (min: 11, avg: 66, max: 223)
#
# Run: 434, exploration: 0.01, score: 12
# Scores: (min: 11, avg: 64.13, max: 223)
#
# Run: 435, exploration: 0.01, score: 39
# Scores: (min: 11, avg: 63.22, max: 223)
#
# Run: 436, exploration: 0.01, score: 64
# Scores: (min: 11, avg: 63.36, max: 223)
#
# Run: 437, exploration: 0.01, score: 51
# Scores: (min: 11, avg: 62.86, max: 223)
#
# Run: 438, exploration: 0.01, score: 136
# Scores: (min: 11, avg: 63.43, max: 223)
#
# Run: 439, exploration: 0.01, score: 27
# Scores: (min: 11, avg: 62.54, max: 223)
#
# Run: 440, exploration: 0.01, score: 81
# Scores: (min: 11, avg: 62.62, max: 223)
#
# Run: 441, exploration: 0.01, score: 245
# Scores: (min: 11, avg: 64.85, max: 245)
#
# Run: 442, exploration: 0.01, score: 169
# Scores: (min: 11, avg: 66.36, max: 245)
#
# Run: 443, exploration: 0.01, score: 14
# Scores: (min: 11, avg: 66.39, max: 245)
#
# Run: 444, exploration: 0.01, score: 125
# Scores: (min: 11, avg: 67.29, max: 245)
#
# Run: 445, exploration: 0.01, score: 12
# Scores: (min: 11, avg: 66.84, max: 245)
#
# Run: 446, exploration: 0.01, score: 46
# Scores: (min: 11, avg: 67.19, max: 245)
#
# Run: 447, exploration: 0.01, score: 130
# Scores: (min: 11, avg: 68.22, max: 245)
#
# Run: 448, exploration: 0.01, score: 12
# Scores: (min: 11, avg: 67.9, max: 245)
#
# Run: 449, exploration: 0.01, score: 93
# Scores: (min: 11, avg: 67.35, max: 245)
#
# Run: 450, exploration: 0.01, score: 72
# Scores: (min: 11, avg: 66.42, max: 245)
#
# Run: 451, exploration: 0.01, score: 97
# Scores: (min: 11, avg: 65.99, max: 245)
#
# Run: 452, exploration: 0.01, score: 34
# Scores: (min: 11, avg: 65.41, max: 245)
#
# Run: 453, exploration: 0.01, score: 155
# Scores: (min: 11, avg: 66.48, max: 245)
#
# Run: 454, exploration: 0.01, score: 27
# Scores: (min: 11, avg: 65.77, max: 245)
#
# Run: 455, exploration: 0.01, score: 60
# Scores: (min: 11, avg: 66.09, max: 245)
#
# Run: 456, exploration: 0.01, score: 31
# Scores: (min: 11, avg: 66.28, max: 245)
#
# Run: 457, exploration: 0.01, score: 31
# Scores: (min: 11, avg: 64.8, max: 245)
#
# Run: 458, exploration: 0.01, score: 201
# Scores: (min: 11, avg: 66.08, max: 245)
#
# Run: 459, exploration: 0.01, score: 41
# Scores: (min: 11, avg: 66.36, max: 245)
#
# Run: 460, exploration: 0.01, score: 92
# Scores: (min: 11, avg: 67.15, max: 245)
#
# Run: 461, exploration: 0.01, score: 25
# Scores: (min: 11, avg: 67.29, max: 245)
#
# Run: 462, exploration: 0.01, score: 69
# Scores: (min: 11, avg: 66.66, max: 245)
#
# Run: 463, exploration: 0.01, score: 25
# Scores: (min: 11, avg: 66.4, max: 245)
#
# Run: 464, exploration: 0.01, score: 166
# Scores: (min: 11, avg: 67.25, max: 245)
#
# Run: 465, exploration: 0.01, score: 143
# Scores: (min: 11, avg: 67.66, max: 245)
#
# Run: 466, exploration: 0.01, score: 19
# Scores: (min: 11, avg: 67.67, max: 245)
#
# Run: 467, exploration: 0.01, score: 90
# Scores: (min: 11, avg: 67.19, max: 245)
#
# Run: 468, exploration: 0.01, score: 36
# Scores: (min: 11, avg: 66.22, max: 245)
#
# Run: 469, exploration: 0.01, score: 25
# Scores: (min: 11, avg: 66.16, max: 245)
#
# Run: 470, exploration: 0.01, score: 22
# Scores: (min: 11, avg: 65.97, max: 245)
#
# Run: 471, exploration: 0.01, score: 96
# Scores: (min: 11, avg: 66.46, max: 245)
#
# Run: 472, exploration: 0.01, score: 84
# Scores: (min: 11, avg: 66.88, max: 245)
#
# Run: 473, exploration: 0.01, score: 16
# Scores: (min: 11, avg: 66.57, max: 245)
#
# Run: 474, exploration: 0.01, score: 41
# Scores: (min: 11, avg: 66.59, max: 245)
#
# Run: 475, exploration: 0.01, score: 143
# Scores: (min: 11, avg: 67.62, max: 245)
#
# Run: 476, exploration: 0.01, score: 186
# Scores: (min: 11, avg: 68.78, max: 245)
#
# Run: 477, exploration: 0.01, score: 64
# Scores: (min: 11, avg: 68.3, max: 245)
#
# Run: 478, exploration: 0.01, score: 50
# Scores: (min: 11, avg: 68.28, max: 245)
#
# Run: 479, exploration: 0.01, score: 152
# Scores: (min: 11, avg: 68.57, max: 245)
#
# Run: 480, exploration: 0.01, score: 17
# Scores: (min: 11, avg: 67.09, max: 245)
#
# Run: 481, exploration: 0.01, score: 122
# Scores: (min: 11, avg: 68.11, max: 245)
#
# Run: 482, exploration: 0.01, score: 51
# Scores: (min: 11, avg: 68.09, max: 245)
#
# Run: 483, exploration: 0.01, score: 83
# Scores: (min: 11, avg: 68.23, max: 245)
#
# Run: 484, exploration: 0.01, score: 22
# Scores: (min: 11, avg: 68.12, max: 245)
#
# Run: 485, exploration: 0.01, score: 23
# Scores: (min: 11, avg: 68.2, max: 245)
#
# Run: 486, exploration: 0.01, score: 11
# Scores: (min: 11, avg: 68.2, max: 245)
#
# Run: 487, exploration: 0.01, score: 57
# Scores: (min: 11, avg: 67.7, max: 245)
#
# Run: 488, exploration: 0.01, score: 59
# Scores: (min: 11, avg: 68.14, max: 245)
#
# Run: 489, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 68.13, max: 245)
#
# Run: 490, exploration: 0.01, score: 66
# Scores: (min: 10, avg: 68.33, max: 245)
#
# Run: 491, exploration: 0.01, score: 44
# Scores: (min: 10, avg: 68.65, max: 245)
#
# Run: 492, exploration: 0.01, score: 67
# Scores: (min: 10, avg: 68.89, max: 245)
#
# Run: 493, exploration: 0.01, score: 110
# Scores: (min: 10, avg: 69.71, max: 245)
#
# Run: 494, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 68.4, max: 245)
#
# Run: 495, exploration: 0.01, score: 56
# Scores: (min: 10, avg: 68.71, max: 245)
#
# Run: 496, exploration: 0.01, score: 114
# Scores: (min: 10, avg: 68.88, max: 245)
#
# Run: 497, exploration: 0.01, score: 14
# Scores: (min: 10, avg: 68.07, max: 245)
#
# Run: 498, exploration: 0.01, score: 137
# Scores: (min: 10, avg: 67.21, max: 245)
# Run: 499, exploration: 0.01, score: 37
# Scores: (min: 10, avg: 67.06, max: 245)
#
# Run: 500, exploration: 0.01, score: 41
# Scores: (min: 10, avg: 66.07, max: 245)
#
# Run: 501, exploration: 0.01, score: 58
# Scores: (min: 10, avg: 65.47, max: 245)
#
# Run: 502, exploration: 0.01, score: 127
# Scores: (min: 10, avg: 64.89, max: 245)
#
# Run: 503, exploration: 0.01, score: 21
# Scores: (min: 10, avg: 63.45, max: 245)
#
# Run: 504, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 62.13, max: 245)
#
# Run: 505, exploration: 0.01, score: 37
# Scores: (min: 10, avg: 61.72, max: 245)
#
# Run: 506, exploration: 0.01, score: 25
# Scores: (min: 10, avg: 61.69, max: 245)
#
# Run: 507, exploration: 0.01, score: 17
# Scores: (min: 10, avg: 61.63, max: 245)
#
# Run: 508, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 61.31, max: 245)
#
# Run: 509, exploration: 0.01, score: 81
# Scores: (min: 10, avg: 61.9, max: 245)
#
# Run: 510, exploration: 0.01, score: 211
# Scores: (min: 10, avg: 63.9, max: 245)
#
# Run: 511, exploration: 0.01, score: 20
# Scores: (min: 10, avg: 63.98, max: 245)
#
# Run: 512, exploration: 0.01, score: 71
# Scores: (min: 10, avg: 64.48, max: 245)
#
# Run: 513, exploration: 0.01, score: 25
# Scores: (min: 10, avg: 63.68, max: 245)
#
# Run: 514, exploration: 0.01, score: 57
# Scores: (min: 10, avg: 64.02, max: 245)
#
# Run: 515, exploration: 0.01, score: 116
# Scores: (min: 10, avg: 64.47, max: 245)
#
# Run: 516, exploration: 0.01, score: 210
# Scores: (min: 10, avg: 65.52, max: 245)
#
# Run: 517, exploration: 0.01, score: 131
# Scores: (min: 10, avg: 66.24, max: 245)
#
# Run: 518, exploration: 0.01, score: 36
# Scores: (min: 10, avg: 66.37, max: 245)
#
# Run: 519, exploration: 0.01, score: 102
# Scores: (min: 10, avg: 66.93, max: 245)
#
# Run: 520, exploration: 0.01, score: 88
# Scores: (min: 10, avg: 66.98, max: 245)
#
# Run: 521, exploration: 0.01, score: 65
# Scores: (min: 10, avg: 67.51, max: 245)
#
# Run: 522, exploration: 0.01, score: 22
# Scores: (min: 10, avg: 67.08, max: 245)
#
# Run: 523, exploration: 0.01, score: 51
# Scores: (min: 10, avg: 67.23, max: 245)
#
# Run: 524, exploration: 0.01, score: 32
# Scores: (min: 10, avg: 67.04, max: 245)
#
# Run: 525, exploration: 0.01, score: 116
# Scores: (min: 10, avg: 67.7, max: 245)
#
# Run: 526, exploration: 0.01, score: 71
# Scores: (min: 10, avg: 67.5, max: 245)
#
# Run: 527, exploration: 0.01, score: 146
# Scores: (min: 10, avg: 68.84, max: 245)
#
# Run: 528, exploration: 0.01, score: 121
# Scores: (min: 10, avg: 69.57, max: 245)
#
# Run: 529, exploration: 0.01, score: 58
# Scores: (min: 10, avg: 69.77, max: 245)
#
# Run: 530, exploration: 0.01, score: 96
# Scores: (min: 10, avg: 70.19, max: 245)
#
# Run: 531, exploration: 0.01, score: 39
# Scores: (min: 10, avg: 70.28, max: 245)
#
# Run: 532, exploration: 0.01, score: 17
# Scores: (min: 10, avg: 70.33, max: 245)
#
# Run: 533, exploration: 0.01, score: 41
# Scores: (min: 10, avg: 70.29, max: 245)
#
# Run: 534, exploration: 0.01, score: 35
# Scores: (min: 10, avg: 70.52, max: 245)
#
# Run: 535, exploration: 0.01, score: 170
# Scores: (min: 10, avg: 71.83, max: 245)
#
# Run: 536, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 71.31, max: 245)
#
# Run: 537, exploration: 0.01, score: 130
# Scores: (min: 10, avg: 72.1, max: 245)
#
# Run: 538, exploration: 0.01, score: 63
# Scores: (min: 10, avg: 71.37, max: 245)
#
# Run: 539, exploration: 0.01, score: 124
# Scores: (min: 10, avg: 72.34, max: 245)
#
# Run: 540, exploration: 0.01, score: 157
# Scores: (min: 10, avg: 73.1, max: 245)
#
# Run: 541, exploration: 0.01, score: 24
# Scores: (min: 10, avg: 70.89, max: 211)
#
# Run: 542, exploration: 0.01, score: 170
# Scores: (min: 10, avg: 70.9, max: 211)
#
# Run: 543, exploration: 0.01, score: 57
# Scores: (min: 10, avg: 71.33, max: 211)
#
# Run: 544, exploration: 0.01, score: 162
# Scores: (min: 10, avg: 71.7, max: 211)
#
# Run: 545, exploration: 0.01, score: 17
# Scores: (min: 10, avg: 71.75, max: 211)
#
# Run: 546, exploration: 0.01, score: 49
# Scores: (min: 10, avg: 71.78, max: 211)
#
# Run: 547, exploration: 0.01, score: 28
# Scores: (min: 10, avg: 70.76, max: 211)
#
# Run: 548, exploration: 0.01, score: 23
# Scores: (min: 10, avg: 70.87, max: 211)
#
# Run: 549, exploration: 0.01, score: 43
# Scores: (min: 10, avg: 70.37, max: 211)
#
# Run: 550, exploration: 0.01, score: 99
# Scores: (min: 10, avg: 70.64, max: 211)
#
# Run: 551, exploration: 0.01, score: 137
# Scores: (min: 10, avg: 71.04, max: 211)
#
# Run: 552, exploration: 0.01, score: 105
# Scores: (min: 10, avg: 71.75, max: 211)
#
# Run: 553, exploration: 0.01, score: 145
# Scores: (min: 10, avg: 71.65, max: 211)
#
# Run: 554, exploration: 0.01, score: 95
# Scores: (min: 10, avg: 72.33, max: 211)
#
# Run: 555, exploration: 0.01, score: 14
# Scores: (min: 10, avg: 71.87, max: 211)
#
# Run: 556, exploration: 0.01, score: 78
# Scores: (min: 10, avg: 72.34, max: 211)
#
# Run: 557, exploration: 0.01, score: 111
# Scores: (min: 10, avg: 73.14, max: 211)
#
# Run: 558, exploration: 0.01, score: 108
# Scores: (min: 10, avg: 72.21, max: 211)
#
# Run: 559, exploration: 0.01, score: 179
# Scores: (min: 10, avg: 73.59, max: 211)
#
# Run: 560, exploration: 0.01, score: 51
# Scores: (min: 10, avg: 73.18, max: 211)
#
# Run: 561, exploration: 0.01, score: 28
# Scores: (min: 10, avg: 73.21, max: 211)
#
# Run: 562, exploration: 0.01, score: 101
# Scores: (min: 10, avg: 73.53, max: 211)
#
# Run: 563, exploration: 0.01, score: 111
# Scores: (min: 10, avg: 74.39, max: 211)
#
# Run: 564, exploration: 0.01, score: 58
# Scores: (min: 10, avg: 73.31, max: 211)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-dde5d7613f3f> in <module>
#       1 GAMMA = 0.50
# ----> 2 cartpole()
#
# <ipython-input-1-bea6327a4fd8> in cartpole()
#      86                 score_logger.add_score(step, run)
#      87                 break
# ---> 88             dqn_solver.experience_replay()
#      89
#
# <ipython-input-1-bea6327a4fd8> in experience_replay(self)
#      53             q_update = reward
#      54             if not terminal:
# ---> 55                 q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))
#      56             q_values = self.model.predict(state)
#      57             q_values[0][action] = q_update
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1460                                             verbose=verbose,
#    1461                                             steps=steps,
# -> 1462                                             callbacks=callbacks)
#    1463
#    1464     def train_on_batch(self, x, y,
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps, callbacks)
#     322             batch_logs = {'batch': batch_index, 'size': len(batch_ids)}
#     323             callbacks._call_batch_hook('predict', 'begin', batch_index, batch_logs)
# --> 324             batch_outs = f(ins_batch)
#     325             batch_outs = to_list(batch_outs)
#     326             if batch_index == 0:
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\keras\backend.py in __call__(self, inputs)
#    3725         value = math_ops.cast(value, tensor.dtype)
#    3726       converted_inputs.append(value)
# -> 3727     outputs = self._graph_fn(*converted_inputs)
#    3728
#    3729     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    1549       TypeError: For invalid positional/keyword argument combinations.
#    1550     """
# -> 1551     return self._call_impl(args, kwargs)
#    1552
#    1553   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1589       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1590           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1591     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1592
#    1593   def _filtered_call(self, args, kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
LEARNING_RATE = 0.0001
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 16
# Scores: (min: 16, avg: 16, max: 16)
#
# Run: 2, exploration: 0.810157377815473, score: 46
# Scores: (min: 16, avg: 31, max: 46)
#
# Run: 3, exploration: 0.7590483508202912, score: 14
# Scores: (min: 14, avg: 25.333333333333332, max: 46)
#
# Run: 4, exploration: 0.7111635524897149, score: 14
# Scores: (min: 14, avg: 22.5, max: 46)
#
# Run: 5, exploration: 0.6596532430440636, score: 16
# Scores: (min: 14, avg: 21.2, max: 46)
#
# Run: 6, exploration: 0.6369088258938781, score: 8
# Scores: (min: 8, avg: 19, max: 46)
#
# Run: 7, exploration: 0.6057704364907278, score: 11
# Scores: (min: 8, avg: 17.857142857142858, max: 46)
#
# Run: 8, exploration: 0.5398075216808175, score: 24
# Scores: (min: 8, avg: 18.625, max: 46)
#
# Run: 9, exploration: 0.483444593917636, score: 23
# Scores: (min: 8, avg: 19.11111111111111, max: 46)
#
# Run: 10, exploration: 0.4598090507939749, score: 11
# Scores: (min: 8, avg: 18.3, max: 46)
#
# Run: 11, exploration: 0.4417353564707963, score: 9
# Scores: (min: 8, avg: 17.454545454545453, max: 46)
#
# Run: 12, exploration: 0.4222502236424958, score: 10
# Scores: (min: 8, avg: 16.833333333333332, max: 46)
#
# Run: 13, exploration: 0.4036245882390106, score: 10
# Scores: (min: 8, avg: 16.307692307692307, max: 46)
#
# Run: 14, exploration: 0.3819719776053028, score: 12
# Scores: (min: 8, avg: 16, max: 46)
#
# Run: 15, exploration: 0.3632974174544486, score: 11
# Scores: (min: 8, avg: 15.666666666666666, max: 46)
#
# Run: 16, exploration: 0.3472722151889232, score: 10
# Scores: (min: 8, avg: 15.3125, max: 46)
#
# Run: 17, exploration: 0.33195389135223546, score: 10
# Scores: (min: 8, avg: 15, max: 46)
#
# Run: 18, exploration: 0.31890579420988907, score: 9
# Scores: (min: 8, avg: 14.666666666666666, max: 46)
#
# Run: 19, exploration: 0.3033145315372582, score: 11
# Scores: (min: 8, avg: 14.473684210526315, max: 46)
#
# Run: 20, exploration: 0.28704309604425327, score: 12
# Scores: (min: 8, avg: 14.35, max: 46)
#
# Run: 21, exploration: 0.2757603055760701, score: 9
# Scores: (min: 8, avg: 14.095238095238095, max: 46)
#
# Run: 22, exploration: 0.26359640222486147, score: 10
# Scores: (min: 8, avg: 13.909090909090908, max: 46)
#
# Run: 23, exploration: 0.2532352299289372, score: 9
# Scores: (min: 8, avg: 13.695652173913043, max: 46)
#
# Run: 24, exploration: 0.24206491716205145, score: 10
# Scores: (min: 8, avg: 13.541666666666666, max: 46)
#
# Run: 25, exploration: 0.231387331601191, score: 10
# Scores: (min: 8, avg: 13.4, max: 46)
#
# Run: 26, exploration: 0.22007483514733558, score: 11
# Scores: (min: 8, avg: 13.307692307692308, max: 46)
#
# Run: 27, exploration: 0.20619134658263935, score: 14
# Scores: (min: 8, avg: 13.333333333333334, max: 46)
#
# Run: 28, exploration: 0.19808659230739353, score: 9
# Scores: (min: 8, avg: 13.178571428571429, max: 46)
#
# Run: 29, exploration: 0.1903004112552766, score: 9
# Scores: (min: 8, avg: 13.03448275862069, max: 46)
#
# Run: 30, exploration: 0.182820281282489, score: 9
# Scores: (min: 8, avg: 12.9, max: 46)
#
# Run: 31, exploration: 0.17214774642209296, score: 13
# Scores: (min: 8, avg: 12.903225806451612, max: 46)
#
# Run: 32, exploration: 0.16291280823111093, score: 12
# Scores: (min: 8, avg: 12.875, max: 46)
#
# Run: 33, exploration: 0.1549480222912372, score: 11
# Scores: (min: 8, avg: 12.818181818181818, max: 46)
#
# Run: 34, exploration: 0.14885748713096328, score: 9
# Scores: (min: 8, avg: 12.705882352941176, max: 46)
#
# Run: 35, exploration: 0.14157986400593744, score: 11
# Scores: (min: 8, avg: 12.657142857142857, max: 46)
#
# Run: 36, exploration: 0.13264825480308728, score: 14
# Scores: (min: 8, avg: 12.694444444444445, max: 46)
#
# Run: 37, exploration: 0.12679708435358925, score: 10
# Scores: (min: 8, avg: 12.621621621621621, max: 46)
#
# Run: 38, exploration: 0.12181307688414106, score: 9
# Scores: (min: 8, avg: 12.526315789473685, max: 46)
#
# Run: 39, exploration: 0.11643985070121858, score: 10
# Scores: (min: 8, avg: 12.461538461538462, max: 46)
#
# Run: 40, exploration: 0.11186295456362313, score: 9
# Scores: (min: 8, avg: 12.375, max: 46)
#
# Run: 41, exploration: 0.10746596228306791, score: 9
# Scores: (min: 8, avg: 12.292682926829269, max: 46)
#
# Run: 42, exploration: 0.10068643904747315, score: 14
# Scores: (min: 8, avg: 12.333333333333334, max: 46)
#
# Run: 43, exploration: 0.09624511776741324, score: 10
# Scores: (min: 8, avg: 12.279069767441861, max: 46)
#
# Run: 44, exploration: 0.09246201511725258, score: 9
# Scores: (min: 8, avg: 12.204545454545455, max: 46)
#
# Run: 45, exploration: 0.0888276147181114, score: 9
# Scores: (min: 8, avg: 12.133333333333333, max: 46)
#
# Run: 46, exploration: 0.08533607153708872, score: 9
# Scores: (min: 8, avg: 12.065217391304348, max: 46)
#
# Run: 47, exploration: 0.08157186144027828, score: 10
# Scores: (min: 8, avg: 12.02127659574468, max: 46)
#
# Run: 48, exploration: 0.07758382377679894, score: 11
# Scores: (min: 8, avg: 12, max: 46)
#
# Run: 49, exploration: 0.07416156859737154, score: 10
# Scores: (min: 8, avg: 11.959183673469388, max: 46)
#
# Run: 50, exploration: 0.0708902705368767, score: 10
# Scores: (min: 8, avg: 11.92, max: 46)
#
# Run: 51, exploration: 0.0677632708131484, score: 10
# Scores: (min: 8, avg: 11.882352941176471, max: 46)
#
# Run: 52, exploration: 0.06542683706543727, score: 8
# Scores: (min: 8, avg: 11.807692307692308, max: 46)
#
# Run: 53, exploration: 0.06285510723190912, score: 9
# Scores: (min: 8, avg: 11.754716981132075, max: 46)
#
# Run: 54, exploration: 0.060687903789832374, score: 8
# Scores: (min: 8, avg: 11.685185185185185, max: 46)
#
# Run: 55, exploration: 0.05772088009124167, score: 11
# Scores: (min: 8, avg: 11.672727272727272, max: 46)
#
# Run: 56, exploration: 0.05573070148010834, score: 8
# Scores: (min: 8, avg: 11.607142857142858, max: 46)
#
# Run: 57, exploration: 0.05327239673939179, score: 10
# Scores: (min: 8, avg: 11.578947368421053, max: 46)
#
# Run: 58, exploration: 0.05143559895690903, score: 8
# Scores: (min: 8, avg: 11.517241379310345, max: 46)
#
# Run: 59, exploration: 0.044924885780066794, score: 28
# Scores: (min: 8, avg: 11.796610169491526, max: 46)
#
# Run: 60, exploration: 0.03496560272750046, score: 51
# Scores: (min: 8, avg: 12.45, max: 51)
#
# Run: 61, exploration: 0.03163025067641567, score: 21
# Scores: (min: 8, avg: 12.59016393442623, max: 51)
#
# Run: 62, exploration: 0.03038696179137978, score: 9
# Scores: (min: 8, avg: 12.53225806451613, max: 51)
#
# Run: 63, exploration: 0.029192542808371146, score: 9
# Scores: (min: 8, avg: 12.476190476190476, max: 51)
#
# Run: 64, exploration: 0.0279048474362789, score: 10
# Scores: (min: 8, avg: 12.4375, max: 51)
#
# Run: 65, exploration: 0.02654058308574668, score: 11
# Scores: (min: 8, avg: 12.415384615384616, max: 51)
#
# Run: 66, exploration: 0.02536986677519817, score: 10
# Scores: (min: 8, avg: 12.378787878787879, max: 51)
#
# Run: 67, exploration: 0.02437265452736848, score: 9
# Scores: (min: 8, avg: 12.328358208955224, max: 51)
#
# Run: 68, exploration: 0.022494281437179946, score: 17
# Scores: (min: 8, avg: 12.397058823529411, max: 51)
#
# Run: 69, exploration: 0.021502049198442223, score: 10
# Scores: (min: 8, avg: 12.36231884057971, max: 51)
#
# Run: 70, exploration: 0.020553584742122436, score: 10
# Scores: (min: 8, avg: 12.32857142857143, max: 51)
#
# Run: 71, exploration: 0.019745685882295267, score: 9
# Scores: (min: 8, avg: 12.28169014084507, max: 51)
#
# Run: 72, exploration: 0.018874695352408037, score: 10
# Scores: (min: 8, avg: 12.25, max: 51)
#
# Run: 73, exploration: 0.018042124582040707, score: 10
# Scores: (min: 8, avg: 12.219178082191782, max: 51)
#
# Run: 74, exploration: 0.01724627885940145, score: 10
# Scores: (min: 8, avg: 12.18918918918919, max: 51)
#
# Run: 75, exploration: 0.016485538227150154, score: 10
# Scores: (min: 8, avg: 12.16, max: 51)
#
# Run: 76, exploration: 0.01575835418494799, score: 10
# Scores: (min: 8, avg: 12.131578947368421, max: 51)
#
# Run: 77, exploration: 0.01506324653745902, score: 10
# Scores: (min: 8, avg: 12.103896103896103, max: 51)
#
# Run: 78, exploration: 0.01137656378004644, score: 57
# Scores: (min: 8, avg: 12.679487179487179, max: 57)
#
# Run: 79, exploration: 0.010658869760009713, score: 14
# Scores: (min: 8, avg: 12.69620253164557, max: 57)
#
# Run: 80, exploration: 0.010188702520663827, score: 10
# Scores: (min: 8, avg: 12.6625, max: 57)
#
# Run: 81, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.641975308641975, max: 57)
#
# Run: 82, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.609756097560975, max: 57)
# Run: 83, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.578313253012048, max: 57)
#
# Run: 84, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 12.678571428571429, max: 57)
#
# Run: 85, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 12.788235294117648, max: 57)
#
# Run: 86, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.779069767441861, max: 57)
#
# Run: 87, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.74712643678161, max: 57)
#
# Run: 88, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.715909090909092, max: 57)
#
# Run: 89, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 12.831460674157304, max: 57)
#
# Run: 90, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.78888888888889, max: 57)
#
# Run: 91, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.758241758241759, max: 57)
#
# Run: 92, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.728260869565217, max: 57)
#
# Run: 93, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 13, max: 57)
#
# Run: 94, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.957446808510639, max: 57)
#
# Run: 95, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.926315789473684, max: 57)
#
# Run: 96, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 12.989583333333334, max: 57)
#
# Run: 97, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.948453608247423, max: 57)
#
# Run: 98, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.938775510204081, max: 57)
#
# Run: 99, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 12.94949494949495, max: 57)
#
# Run: 100, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.91, max: 57)
#
# Run: 101, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.86, max: 57)
#
# Run: 102, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 12.66, max: 57)
#
# Run: 103, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 12.87, max: 57)
#
# Run: 104, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 13.02, max: 57)
#
# Run: 105, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 13.12, max: 57)
#
# Run: 106, exploration: 0.01, score: 46
# Scores: (min: 8, avg: 13.5, max: 57)
#
# Run: 107, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 13.59, max: 57)
#
# Run: 108, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 13.59, max: 57)
#
# Run: 109, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 13.51, max: 57)
#
# Run: 110, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.5, max: 57)
#
# Run: 111, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.5, max: 57)
#
# Run: 112, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 13.61, max: 57)
#
# Run: 113, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 13.71, max: 57)
#
# Run: 114, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 13.94, max: 57)
#
# Run: 115, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 14, max: 57)
#
# Run: 116, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 14.42, max: 57)
#
# Run: 117, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 14.6, max: 57)
#
# Run: 118, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 14.72, max: 57)
#
# Run: 119, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 14.92, max: 57)
#
# Run: 120, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 15.11, max: 57)
#
# Run: 121, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 15.26, max: 57)
#
# Run: 122, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 15.36, max: 57)
#
# Run: 123, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 15.48, max: 57)
#
# Run: 124, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 15.69, max: 57)
#
# Run: 125, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 16, max: 57)
#
# Run: 126, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 16.11, max: 57)
#
# Run: 127, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 16.22, max: 57)
#
# Run: 128, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 16.42, max: 57)
#
# Run: 129, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 16.69, max: 57)
#
# Run: 130, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 17.02, max: 57)
#
# Run: 131, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 17.08, max: 57)
#
# Run: 132, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 17.24, max: 57)
#
# Run: 133, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 17.36, max: 57)
#
# Run: 134, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 17.52, max: 57)
#
# Run: 135, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 17.86, max: 57)
#
# Run: 136, exploration: 0.01, score: 53
# Scores: (min: 8, avg: 18.25, max: 57)
#
# Run: 137, exploration: 0.01, score: 66
# Scores: (min: 8, avg: 18.81, max: 66)
#
# Run: 138, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 19.14, max: 66)
#
# Run: 139, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 19.31, max: 66)
#
# Run: 140, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 19.55, max: 66)
#
# Run: 141, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 19.96, max: 66)
#
# Run: 142, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 20.23, max: 66)
#
# Run: 143, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 20.5, max: 66)
#
# Run: 144, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 20.77, max: 66)
#
# Run: 145, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 21.03, max: 66)
#
# Run: 146, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 21.21, max: 66)
#
# Run: 147, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 21.33, max: 66)
#
# Run: 148, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 21.61, max: 66)
#
# Run: 149, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 21.94, max: 66)
#
# Run: 150, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 22.26, max: 66)
#
# Run: 151, exploration: 0.01, score: 62
# Scores: (min: 8, avg: 22.78, max: 66)
#
# Run: 152, exploration: 0.01, score: 59
# Scores: (min: 8, avg: 23.29, max: 66)
#
# Run: 153, exploration: 0.01, score: 144
# Scores: (min: 8, avg: 24.64, max: 144)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-ba617c1cb772> in <module>
#       1 LEARNING_RATE = 0.0001
# ----> 2 cartpole()
#
# <ipython-input-1-bea6327a4fd8> in cartpole()
#      86                 score_logger.add_score(step, run)
#      87                 break
# ---> 88             dqn_solver.experience_replay()
#      89
#
# <ipython-input-1-bea6327a4fd8> in experience_replay(self)
#      54             if not terminal:
#      55                 q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))
# ---> 56             q_values = self.model.predict(state)
#      57             q_values[0][action] = q_update
#      58             self.model.fit(state, q_values, verbose=0)
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1460                                             verbose=verbose,
#    1461                                             steps=steps,
# -> 1462                                             callbacks=callbacks)
#    1463
#    1464     def train_on_batch(self, x, y,
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps, callbacks)
#     322             batch_logs = {'batch': batch_index, 'size': len(batch_ids)}
#     323             callbacks._call_batch_hook('predict', 'begin', batch_index, batch_logs)
# --> 324             batch_outs = f(ins_batch)
#     325             batch_outs = to_list(batch_outs)
#     326             if batch_index == 0:
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\keras\backend.py in __call__(self, inputs)
#    3725         value = math_ops.cast(value, tensor.dtype)
#    3726       converted_inputs.append(value)
# -> 3727     outputs = self._graph_fn(*converted_inputs)
#    3728
#    3729     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    1549       TypeError: For invalid positional/keyword argument combinations.
#    1550     """
# -> 1551     return self._call_impl(args, kwargs)
#    1552
#    1553   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1589       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1590           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1591     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1592
#    1593   def _filtered_call(self, args, kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
LEARNING_RATE = 0.01 #Stopped, This high of a learning rate probably will not meet accuracy threshhold
cartpole()
# Out:
# Run: 1, exploration: 0.9275689688183278, score: 35
# Scores: (min: 35, avg: 35, max: 35)
#
# Run: 2, exploration: 0.8433051360508336, score: 20
# Scores: (min: 20, avg: 27.5, max: 35)
#
# Run: 3, exploration: 0.6935613678313175, score: 40
# Scores: (min: 20, avg: 31.666666666666668, max: 40)
#
# Run: 4, exploration: 0.6149486215357263, score: 25
# Scores: (min: 20, avg: 30, max: 40)
#
# Run: 5, exploration: 0.5704072587541458, score: 16
# Scores: (min: 16, avg: 27.2, max: 40)
#
# Run: 6, exploration: 0.4932355662165453, score: 30
# Scores: (min: 16, avg: 27.666666666666668, max: 40)
#
# Run: 7, exploration: 0.46912134373457726, score: 11
# Scores: (min: 11, avg: 25.285714285714285, max: 40)
#
# Run: 8, exploration: 0.446186062443672, score: 11
# Scores: (min: 11, avg: 23.5, max: 40)
#
# Run: 9, exploration: 0.3632974174544486, score: 42
# Scores: (min: 11, avg: 25.555555555555557, max: 42)
#
# Run: 10, exploration: 0.3017979588795719, score: 38
# Scores: (min: 11, avg: 26.8, max: 42)
#
# Run: 11, exploration: 0.2689348941735696, score: 24
# Scores: (min: 11, avg: 26.545454545454547, max: 42)
#
# Run: 12, exploration: 0.2507092085103961, score: 15
# Scores: (min: 11, avg: 25.583333333333332, max: 42)
#
# Run: 13, exploration: 0.23725980767521673, score: 12
# Scores: (min: 11, avg: 24.53846153846154, max: 42)
#
# Run: 14, exploration: 0.1865228530605915, score: 49
# Scores: (min: 11, avg: 26.285714285714285, max: 49)
#
# Run: 15, exploration: 0.1451730787173275, score: 51
# Scores: (min: 11, avg: 27.933333333333334, max: 51)
#
# Run: 16, exploration: 0.13669828187021155, score: 13
# Scores: (min: 11, avg: 27, max: 51)
#
# Run: 17, exploration: 0.11470197137452155, score: 36
# Scores: (min: 11, avg: 27.529411764705884, max: 51)
#
# Run: 18, exploration: 0.1032418023864836, score: 22
# Scores: (min: 11, avg: 27.22222222222222, max: 51)
#
# Run: 19, exploration: 0.07797369223798889, score: 57
# Scores: (min: 11, avg: 28.789473684210527, max: 57)
#
# Run: 20, exploration: 0.0660860453679829, score: 34
# Scores: (min: 11, avg: 29.05, max: 57)
#
# Run: 21, exploration: 0.06129936495526111, score: 16
# Scores: (min: 11, avg: 28.428571428571427, max: 57)
#
# Run: 22, exploration: 0.05685938874076987, score: 16
# Scores: (min: 11, avg: 27.863636363636363, max: 57)
#
# Run: 23, exploration: 0.05354009722551939, score: 13
# Scores: (min: 11, avg: 27.217391304347824, max: 57)
#
# Run: 24, exploration: 0.05092252885731386, score: 11
# Scores: (min: 11, avg: 26.541666666666668, max: 57)
#
# Run: 25, exploration: 0.04063952250178857, score: 46
# Scores: (min: 11, avg: 27.32, max: 57)
#
# Run: 26, exploration: 0.035317898767708356, score: 29
# Scores: (min: 11, avg: 27.384615384615383, max: 57)
#
# Run: 27, exploration: 0.032924408985721944, score: 15
# Scores: (min: 11, avg: 26.925925925925927, max: 57)
#
# Run: 28, exploration: 0.029192542808371146, score: 25
# Scores: (min: 11, avg: 26.857142857142858, max: 57)
#
# Run: 29, exploration: 0.026673952849996664, score: 19
# Scores: (min: 11, avg: 26.586206896551722, max: 57)
#
# Run: 30, exploration: 0.021502049198442223, score: 44
# Scores: (min: 11, avg: 27.166666666666668, max: 57)
#
# Run: 31, exploration: 0.020044857891939702, score: 15
# Scores: (min: 11, avg: 26.774193548387096, max: 57)
#
# Run: 32, exploration: 0.01461696034160619, score: 64
# Scores: (min: 11, avg: 27.9375, max: 64)
#
# Run: 33, exploration: 0.01, score: 81
# Scores: (min: 11, avg: 29.545454545454547, max: 81)
#
# Run: 34, exploration: 0.01, score: 20
# Scores: (min: 11, avg: 29.264705882352942, max: 81)
#
# Run: 35, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 28.714285714285715, max: 81)
#
# Run: 36, exploration: 0.01, score: 45
# Scores: (min: 10, avg: 29.166666666666668, max: 81)
#
# Run: 37, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 28.72972972972973, max: 81)
#
# Run: 38, exploration: 0.01, score: 22
# Scores: (min: 10, avg: 28.55263157894737, max: 81)
#
# Run: 39, exploration: 0.01, score: 24
# Scores: (min: 10, avg: 28.435897435897434, max: 81)
#
# Run: 40, exploration: 0.01, score: 19
# Scores: (min: 10, avg: 28.2, max: 81)
#
# Run: 41, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 27.75609756097561, max: 81)
#
# Run: 42, exploration: 0.01, score: 37
# Scores: (min: 10, avg: 27.976190476190474, max: 81)
#
# Run: 43, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 27.627906976744185, max: 81)
#
# Run: 44, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 27.25, max: 81)
#
# Run: 45, exploration: 0.01, score: 31
# Scores: (min: 10, avg: 27.333333333333332, max: 81)
#
# Run: 46, exploration: 0.01, score: 17
# Scores: (min: 10, avg: 27.108695652173914, max: 81)
#
# Run: 47, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 26.74468085106383, max: 81)
#
# Run: 48, exploration: 0.01, score: 21
# Scores: (min: 10, avg: 26.625, max: 81)
#
# Run: 49, exploration: 0.01, score: 17
# Scores: (min: 10, avg: 26.428571428571427, max: 81)
#
# Run: 50, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 26.1, max: 81)
#
# Run: 51, exploration: 0.01, score: 17
# Scores: (min: 10, avg: 25.92156862745098, max: 81)
#
# Run: 52, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 25.653846153846153, max: 81)
#
# Run: 53, exploration: 0.01, score: 27
# Scores: (min: 10, avg: 25.67924528301887, max: 81)
#
# Run: 54, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 25.444444444444443, max: 81)
#
# Run: 55, exploration: 0.01, score: 23
# Scores: (min: 10, avg: 25.4, max: 81)
#
# Run: 56, exploration: 0.01, score: 77
# Scores: (min: 10, avg: 26.321428571428573, max: 81)
#
# Run: 57, exploration: 0.01, score: 26
# Scores: (min: 10, avg: 26.31578947368421, max: 81)
#
# Run: 58, exploration: 0.01, score: 21
# Scores: (min: 10, avg: 26.224137931034484, max: 81)
#
# Run: 59, exploration: 0.01, score: 24
# Scores: (min: 10, avg: 26.1864406779661, max: 81)
#
# Run: 60, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 25.966666666666665, max: 81)
#
# Run: 61, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 25.75409836065574, max: 81)
#
# Run: 62, exploration: 0.01, score: 42
# Scores: (min: 10, avg: 26.016129032258064, max: 81)
#
# Run: 63, exploration: 0.01, score: 22
# Scores: (min: 10, avg: 25.952380952380953, max: 81)
#
# Run: 64, exploration: 0.01, score: 17
# Scores: (min: 10, avg: 25.8125, max: 81)
#
# Run: 65, exploration: 0.01, score: 44
# Scores: (min: 10, avg: 26.092307692307692, max: 81)
#
# Run: 66, exploration: 0.01, score: 15
# Scores: (min: 10, avg: 25.924242424242426, max: 81)
#
# Run: 67, exploration: 0.01, score: 16
# Scores: (min: 10, avg: 25.776119402985074, max: 81)
#
# Run: 68, exploration: 0.01, score: 19
# Scores: (min: 10, avg: 25.676470588235293, max: 81)
#
# Run: 69, exploration: 0.01, score: 37
# Scores: (min: 10, avg: 25.840579710144926, max: 81)
#
# Run: 70, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 25.65714285714286, max: 81)
#
# Run: 71, exploration: 0.01, score: 20
# Scores: (min: 10, avg: 25.577464788732396, max: 81)
#
# Run: 72, exploration: 0.01, score: 37
# Scores: (min: 10, avg: 25.73611111111111, max: 81)
#
# Run: 73, exploration: 0.01, score: 25
# Scores: (min: 10, avg: 25.726027397260275, max: 81)
#
# Run: 74, exploration: 0.01, score: 16
# Scores: (min: 10, avg: 25.594594594594593, max: 81)
#
# Run: 75, exploration: 0.01, score: 17
# Scores: (min: 10, avg: 25.48, max: 81)
#
# Run: 76, exploration: 0.01, score: 17
# Scores: (min: 10, avg: 25.36842105263158, max: 81)
#
# Run: 77, exploration: 0.01, score: 17
# Scores: (min: 10, avg: 25.25974025974026, max: 81)
#
# Run: 78, exploration: 0.01, score: 27
# Scores: (min: 10, avg: 25.28205128205128, max: 81)
#
# Run: 79, exploration: 0.01, score: 14
# Scores: (min: 10, avg: 25.139240506329113, max: 81)
#
# Run: 80, exploration: 0.01, score: 24
# Scores: (min: 10, avg: 25.125, max: 81)
#
# Run: 81, exploration: 0.01, score: 64
# Scores: (min: 10, avg: 25.604938271604937, max: 81)
#
# Run: 82, exploration: 0.01, score: 28
# Scores: (min: 10, avg: 25.634146341463413, max: 81)
#
# Run: 83, exploration: 0.01, score: 22
# Scores: (min: 10, avg: 25.59036144578313, max: 81)
#
# Run: 84, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 25.428571428571427, max: 81)
#
# Run: 85, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 25.258823529411764, max: 81)
#
# Run: 86, exploration: 0.01, score: 25
# Scores: (min: 10, avg: 25.25581395348837, max: 81)
#
# Run: 87, exploration: 0.01, score: 122
# Scores: (min: 10, avg: 26.367816091954023, max: 122)
#
# Run: 88, exploration: 0.01, score: 22
# Scores: (min: 10, avg: 26.318181818181817, max: 122)
# Run: 89, exploration: 0.01, score: 58
# Scores: (min: 10, avg: 26.674157303370787, max: 122)
#
# Run: 90, exploration: 0.01, score: 18
# Scores: (min: 10, avg: 26.57777777777778, max: 122)
#
# Run: 91, exploration: 0.01, score: 69
# Scores: (min: 10, avg: 27.043956043956044, max: 122)
#
# Run: 92, exploration: 0.01, score: 29
# Scores: (min: 10, avg: 27.065217391304348, max: 122)
#
# Run: 93, exploration: 0.01, score: 22
# Scores: (min: 10, avg: 27.010752688172044, max: 122)
#
# Run: 94, exploration: 0.01, score: 27
# Scores: (min: 10, avg: 27.01063829787234, max: 122)
#
# Run: 95, exploration: 0.01, score: 84
# Scores: (min: 10, avg: 27.610526315789475, max: 122)
#
# Run: 96, exploration: 0.01, score: 31
# Scores: (min: 10, avg: 27.645833333333332, max: 122)
#
# Run: 97, exploration: 0.01, score: 55
# Scores: (min: 10, avg: 27.927835051546392, max: 122)
#
# Run: 98, exploration: 0.01, score: 43
# Scores: (min: 10, avg: 28.081632653061224, max: 122)
#
# Run: 99, exploration: 0.01, score: 20
# Scores: (min: 10, avg: 28, max: 122)
#
# Run: 100, exploration: 0.01, score: 20
# Scores: (min: 10, avg: 27.92, max: 122)
#
# Run: 101, exploration: 0.01, score: 17
# Scores: (min: 10, avg: 27.74, max: 122)
#
# Run: 102, exploration: 0.01, score: 30
# Scores: (min: 10, avg: 27.84, max: 122)
#
# Run: 103, exploration: 0.01, score: 15
# Scores: (min: 10, avg: 27.59, max: 122)
#
# Run: 104, exploration: 0.01, score: 62
# Scores: (min: 10, avg: 27.96, max: 122)
#
# Run: 105, exploration: 0.01, score: 32
# Scores: (min: 10, avg: 28.12, max: 122)
#
# Run: 106, exploration: 0.01, score: 79
# Scores: (min: 10, avg: 28.61, max: 122)
#
# Run: 107, exploration: 0.01, score: 28
# Scores: (min: 10, avg: 28.78, max: 122)
#
# Run: 108, exploration: 0.01, score: 15
# Scores: (min: 10, avg: 28.82, max: 122)
#
# Run: 109, exploration: 0.01, score: 52
# Scores: (min: 10, avg: 28.92, max: 122)
#
# Run: 110, exploration: 0.01, score: 80
# Scores: (min: 10, avg: 29.34, max: 122)
#
# Run: 111, exploration: 0.01, score: 14
# Scores: (min: 10, avg: 29.24, max: 122)
#
# Run: 112, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 29.18, max: 122)
#
# Run: 113, exploration: 0.01, score: 88
# Scores: (min: 9, avg: 29.94, max: 122)
#
# Run: 114, exploration: 0.01, score: 84
# Scores: (min: 9, avg: 30.29, max: 122)
#
# Run: 115, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 29.99, max: 122)
#
# Run: 116, exploration: 0.01, score: 95
# Scores: (min: 9, avg: 30.81, max: 122)
#
# Run: 117, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 30.58, max: 122)
#
# Run: 118, exploration: 0.01, score: 49
# Scores: (min: 9, avg: 30.85, max: 122)
#
# Run: 119, exploration: 0.01, score: 47
# Scores: (min: 9, avg: 30.75, max: 122)
#
# Run: 120, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 30.59, max: 122)
#
# Run: 121, exploration: 0.01, score: 43
# Scores: (min: 9, avg: 30.86, max: 122)
#
# Run: 122, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 30.85, max: 122)
#
# Run: 123, exploration: 0.01, score: 17
# Scores: (min: 9, avg: 30.89, max: 122)
#
# Run: 124, exploration: 0.01, score: 47
# Scores: (min: 9, avg: 31.25, max: 122)
#
# Run: 125, exploration: 0.01, score: 28
# Scores: (min: 9, avg: 31.07, max: 122)
#
# Run: 126, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 30.91, max: 122)
#
# Run: 127, exploration: 0.01, score: 76
# Scores: (min: 9, avg: 31.52, max: 122)
#
# Run: 128, exploration: 0.01, score: 57
# Scores: (min: 9, avg: 31.84, max: 122)
#
# Run: 129, exploration: 0.01, score: 67
# Scores: (min: 9, avg: 32.32, max: 122)
#
# Run: 130, exploration: 0.01, score: 33
# Scores: (min: 9, avg: 32.21, max: 122)
#
# Run: 131, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 32.17, max: 122)
#
# Run: 132, exploration: 0.01, score: 56
# Scores: (min: 9, avg: 32.09, max: 122)
#
# Run: 133, exploration: 0.01, score: 23
# Scores: (min: 9, avg: 31.51, max: 122)
#
# Run: 134, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 31.51, max: 122)
#
# Run: 135, exploration: 0.01, score: 44
# Scores: (min: 9, avg: 31.85, max: 122)
#
# Run: 136, exploration: 0.01, score: 36
# Scores: (min: 9, avg: 31.76, max: 122)
#
# Run: 137, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 31.78, max: 122)
#
# Run: 138, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 31.72, max: 122)
#
# Run: 139, exploration: 0.01, score: 28
# Scores: (min: 9, avg: 31.76, max: 122)
#
# Run: 140, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 31.71, max: 122)
#
# Run: 141, exploration: 0.01, score: 19
# Scores: (min: 9, avg: 31.8, max: 122)
#
# Run: 142, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 31.57, max: 122)
#
# Run: 143, exploration: 0.01, score: 29
# Scores: (min: 9, avg: 31.73, max: 122)
#
# Run: 144, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 31.74, max: 122)
#
# Run: 145, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 31.55, max: 122)
#
# Run: 146, exploration: 0.01, score: 37
# Scores: (min: 9, avg: 31.75, max: 122)
#
# Run: 147, exploration: 0.01, score: 30
# Scores: (min: 9, avg: 31.95, max: 122)
#
# Run: 148, exploration: 0.01, score: 64
# Scores: (min: 9, avg: 32.38, max: 122)
#
# Run: 149, exploration: 0.01, score: 101
# Scores: (min: 9, avg: 33.22, max: 122)
#
# Run: 150, exploration: 0.01, score: 148
# Scores: (min: 9, avg: 34.6, max: 148)
#
# Run: 151, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 34.59, max: 148)
#
# Run: 152, exploration: 0.01, score: 27
# Scores: (min: 9, avg: 34.74, max: 148)
#
# Run: 153, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 34.61, max: 148)
#
# Run: 154, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 34.61, max: 148)
#
# Run: 155, exploration: 0.01, score: 87
# Scores: (min: 9, avg: 35.25, max: 148)
#
# Run: 156, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 34.59, max: 148)
#
# Run: 157, exploration: 0.01, score: 17
# Scores: (min: 9, avg: 34.5, max: 148)
#
# Run: 158, exploration: 0.01, score: 43
# Scores: (min: 9, avg: 34.72, max: 148)
#
# Run: 159, exploration: 0.01, score: 35
# Scores: (min: 9, avg: 34.83, max: 148)
#
# Run: 160, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 34.82, max: 148)
#
# Run: 161, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 34.87, max: 148)
#
# Run: 162, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 34.66, max: 148)
#
# Run: 163, exploration: 0.01, score: 52
# Scores: (min: 9, avg: 34.96, max: 148)
#
# Run: 164, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 34.97, max: 148)
#
# Run: 165, exploration: 0.01, score: 56
# Scores: (min: 9, avg: 35.09, max: 148)
#
# Run: 166, exploration: 0.01, score: 107
# Scores: (min: 9, avg: 36.01, max: 148)
#
# Run: 167, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 36.05, max: 148)
#
# Run: 168, exploration: 0.01, score: 100
# Scores: (min: 9, avg: 36.86, max: 148)
#
# Run: 169, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 36.7, max: 148)
#
# Run: 170, exploration: 0.01, score: 24
# Scores: (min: 9, avg: 36.81, max: 148)
#
# Run: 171, exploration: 0.01, score: 32
# Scores: (min: 9, avg: 36.93, max: 148)
#
# Run: 172, exploration: 0.01, score: 91
# Scores: (min: 9, avg: 37.47, max: 148)
#
# Run: 173, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 37.32, max: 148)
#
# Run: 174, exploration: 0.01, score: 28
# Scores: (min: 9, avg: 37.44, max: 148)
#
# Run: 175, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 37.41, max: 148)
#
# Run: 176, exploration: 0.01, score: 47
# Scores: (min: 9, avg: 37.71, max: 148)
#
# Run: 177, exploration: 0.01, score: 55
# Scores: (min: 9, avg: 38.09, max: 148)
#
# Run: 178, exploration: 0.01, score: 42
# Scores: (min: 9, avg: 38.24, max: 148)
#
# Run: 179, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 38.26, max: 148)
#
# Run: 180, exploration: 0.01, score: 101
# Scores: (min: 9, avg: 39.03, max: 148)
#
# Run: 181, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 38.51, max: 148)
#
# Run: 182, exploration: 0.01, score: 28
# Scores: (min: 9, avg: 38.51, max: 148)
#
# Run: 183, exploration: 0.01, score: 38
# Scores: (min: 9, avg: 38.67, max: 148)
#
# Run: 184, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 38.67, max: 148)
#
# Run: 185, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 38.78, max: 148)
#
# Run: 186, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 38.62, max: 148)
#
# Run: 187, exploration: 0.01, score: 28
# Scores: (min: 9, avg: 37.68, max: 148)
#
# Run: 188, exploration: 0.01, score: 42
# Scores: (min: 9, avg: 37.88, max: 148)
#
# Run: 189, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 37.52, max: 148)
#
# Run: 190, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 37.48, max: 148)
# Run: 191, exploration: 0.01, score: 36
# Scores: (min: 9, avg: 37.15, max: 148)
#
# Run: 192, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 37.02, max: 148)
#
# Run: 193, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 36.94, max: 148)
#
# Run: 194, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 36.89, max: 148)
#
# Run: 195, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 36.23, max: 148)
#
# Run: 196, exploration: 0.01, score: 26
# Scores: (min: 9, avg: 36.18, max: 148)
#
# Run: 197, exploration: 0.01, score: 17
# Scores: (min: 9, avg: 35.8, max: 148)
#
# Run: 198, exploration: 0.01, score: 17
# Scores: (min: 9, avg: 35.54, max: 148)
#
# Run: 199, exploration: 0.01, score: 28
# Scores: (min: 9, avg: 35.62, max: 148)
#
# Run: 200, exploration: 0.01, score: 48
# Scores: (min: 9, avg: 35.9, max: 148)
#
# Run: 201, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 35.83, max: 148)
#
# Run: 202, exploration: 0.01, score: 53
# Scores: (min: 9, avg: 36.06, max: 148)
#
# Run: 203, exploration: 0.01, score: 19
# Scores: (min: 9, avg: 36.1, max: 148)
#
# Run: 204, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 35.59, max: 148)
#
# Run: 205, exploration: 0.01, score: 67
# Scores: (min: 9, avg: 35.94, max: 148)
#
# Run: 206, exploration: 0.01, score: 29
# Scores: (min: 9, avg: 35.44, max: 148)
#
# Run: 207, exploration: 0.01, score: 50
# Scores: (min: 9, avg: 35.66, max: 148)
#
# Run: 208, exploration: 0.01, score: 49
# Scores: (min: 9, avg: 36, max: 148)
#
# Run: 209, exploration: 0.01, score: 41
# Scores: (min: 9, avg: 35.89, max: 148)
#
# Run: 210, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 35.24, max: 148)
#
# Run: 211, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 35.24, max: 148)
#
# Run: 212, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 35.26, max: 148)
#
# Run: 213, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 34.5, max: 148)
#
# Run: 214, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 33.84, max: 148)
#
# Run: 215, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 33.73, max: 148)
#
# Run: 216, exploration: 0.01, score: 26
# Scores: (min: 9, avg: 33.04, max: 148)
#
# Run: 217, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 33.07, max: 148)
#
# Run: 218, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 32.73, max: 148)
#
# Run: 219, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 32.44, max: 148)
#
# Run: 220, exploration: 0.01, score: 25
# Scores: (min: 9, avg: 32.51, max: 148)
#
# Run: 221, exploration: 0.01, score: 64
# Scores: (min: 9, avg: 32.72, max: 148)
#
# Run: 222, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 32.73, max: 148)
#
# Run: 223, exploration: 0.01, score: 38
# Scores: (min: 9, avg: 32.94, max: 148)
#
# Run: 224, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 32.69, max: 148)
#
# Run: 225, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 32.63, max: 148)
#
# Run: 226, exploration: 0.01, score: 30
# Scores: (min: 9, avg: 32.8, max: 148)
#
# Run: 227, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 32.25, max: 148)
#
# Run: 228, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 31.83, max: 148)
#
# Run: 229, exploration: 0.01, score: 34
# Scores: (min: 9, avg: 31.5, max: 148)
#
# Run: 230, exploration: 0.01, score: 81
# Scores: (min: 9, avg: 31.98, max: 148)
#
# Run: 231, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 32.01, max: 148)
#
# Run: 232, exploration: 0.01, score: 35
# Scores: (min: 9, avg: 31.8, max: 148)
#
# Run: 233, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 31.69, max: 148)
#
# Run: 234, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 31.7, max: 148)
#
# Run: 235, exploration: 0.01, score: 23
# Scores: (min: 9, avg: 31.49, max: 148)
#
# Run: 236, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 31.24, max: 148)
#
# Run: 237, exploration: 0.01, score: 19
# Scores: (min: 9, avg: 31.28, max: 148)
#
# Run: 238, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 31.3, max: 148)
#
# Run: 239, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 31.16, max: 148)
#
# Run: 240, exploration: 0.01, score: 31
# Scores: (min: 9, avg: 31.33, max: 148)
#
# Run: 241, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 31.26, max: 148)
#
# Run: 242, exploration: 0.01, score: 60
# Scores: (min: 9, avg: 31.72, max: 148)
#
# Run: 243, exploration: 0.01, score: 17
# Scores: (min: 9, avg: 31.6, max: 148)
#
# Run: 244, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 31.59, max: 148)
#
# Run: 245, exploration: 0.01, score: 83
# Scores: (min: 9, avg: 32.3, max: 148)
#
# Run: 246, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 32.13, max: 148)
#
# Run: 247, exploration: 0.01, score: 36
# Scores: (min: 9, avg: 32.19, max: 148)
#
# Run: 248, exploration: 0.01, score: 19
# Scores: (min: 9, avg: 31.74, max: 148)
#
# Run: 249, exploration: 0.01, score: 51
# Scores: (min: 9, avg: 31.24, max: 148)
#
# Run: 250, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 29.96, max: 107)
#
# Run: 251, exploration: 0.01, score: 33
# Scores: (min: 9, avg: 30.13, max: 107)
#
# Run: 252, exploration: 0.01, score: 64
# Scores: (min: 9, avg: 30.5, max: 107)
#
# Run: 253, exploration: 0.01, score: 27
# Scores: (min: 9, avg: 30.63, max: 107)
#
# Run: 254, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 30.68, max: 107)
#
# Run: 255, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 29.96, max: 107)
#
# Run: 256, exploration: 0.01, score: 37
# Scores: (min: 9, avg: 30.22, max: 107)
#
# Run: 257, exploration: 0.01, score: 77
# Scores: (min: 9, avg: 30.82, max: 107)
#
# Run: 258, exploration: 0.01, score: 78
# Scores: (min: 9, avg: 31.17, max: 107)
#
# Run: 259, exploration: 0.01, score: 34
# Scores: (min: 9, avg: 31.16, max: 107)
#
# Run: 260, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 31.2, max: 107)
#
# Run: 261, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 31.22, max: 107)
#
# Run: 262, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 31.11, max: 107)
#
# Run: 263, exploration: 0.01, score: 55
# Scores: (min: 9, avg: 31.14, max: 107)
#
# Run: 264, exploration: 0.01, score: 38
# Scores: (min: 9, avg: 31.34, max: 107)
#
# Run: 265, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 30.88, max: 107)
#
# Run: 266, exploration: 0.01, score: 80
# Scores: (min: 9, avg: 30.61, max: 101)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-0cf4e1898bd5> in <module>
#       1 LEARNING_RATE = 0.01
# ----> 2 cartpole()
#
# <ipython-input-1-bea6327a4fd8> in cartpole()
#      86                 score_logger.add_score(step, run)
#      87                 break
# ---> 88             dqn_solver.experience_replay()
#      89
#
# <ipython-input-1-bea6327a4fd8> in experience_replay(self)
#      56             q_values = self.model.predict(state)
#      57             q_values[0][action] = q_update
# ---> 58             self.model.fit(state, q_values, verbose=0)
#      59         self.exploration_rate *= EXPLORATION_DECAY
#      60         self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     190                                     'pass shuffle="batch".')
#     191                 batch_logs = {'batch': batch_index, 'size': len(batch_ids)}
# --> 192                 callbacks._call_batch_hook('train', 'begin', batch_index, batch_logs)
#     193                 for i in indices_for_conversion_to_dense:
#     194                     ins_batch[i] = ins_batch[i].toarray()
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#      86         self._delta_ts[hook_name].append(time.time() - t_before_callbacks)
#      87
# ---> 88         delta_t_median = np.median(self._delta_ts[hook_name])
#      89         if (self._delta_t_batch > 0. and
#      90            delta_t_median > 0.95 * self._delta_t_batch and
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py in median(a, axis, out, overwrite_input, keepdims)
#    3495     """
#    3496     r, k = _ureduce(a, func=_median, axis=axis, out=out,
# -> 3497                     overwrite_input=overwrite_input)
#    3498     if keepdims:
#    3499         return r.reshape(k)
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py in _ureduce(a, func, **kwargs)
#    3403         keepdim = (1,) * a.ndim
#    3404
# -> 3405     r = func(a, **kwargs)
#    3406     return r, keepdim
#    3407
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py in _median(a, axis, out, overwrite_input)
#    3528             part = a
#    3529     else:
# -> 3530         part = partition(a, kth, axis=axis)
#    3531
#    3532     if part.shape == ():
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in partition(a, kth, axis, kind, order)
#     732     else:
#     733         a = asanyarray(a).copy(order="K")
# --> 734     a.partition(kth, axis=axis, kind=kind, order=order)
#     735     return a
#     736
#
# KeyboardInterrupt:

# %%
EXPLORATION_MAX = 1.5
EXPLORATION_MIN = 0.1
EXPLORATION_DECAY = 0.999
cartpole()
# Out:
# Run: 1, exploration: 1.5, score: 18
# Scores: (min: 18, avg: 18, max: 18)
#
# Run: 2, exploration: 1.482098670741313, score: 14
# Scores: (min: 14, avg: 16, max: 18)
#
# Run: 3, exploration: 1.4600221387043475, score: 16
# Scores: (min: 14, avg: 16, max: 18)
#
# Run: 4, exploration: 1.4111917889414172, score: 35
# Scores: (min: 14, avg: 20.75, max: 35)
#
# Run: 5, exploration: 1.3585467674380012, score: 39
# Scores: (min: 14, avg: 24.4, max: 39)
#
# Run: 6, exploration: 1.3210165657118556, score: 29
# Scores: (min: 14, avg: 25.166666666666668, max: 39)
#
# Run: 7, exploration: 1.3065578218677316, score: 12
# Scores: (min: 12, avg: 23.285714285714285, max: 39)
#
# Run: 8, exploration: 1.290965074024554, score: 13
# Scores: (min: 12, avg: 22, max: 39)
#
# Run: 9, exploration: 1.262860076651409, score: 23
# Scores: (min: 12, avg: 22.11111111111111, max: 39)
#
# Run: 10, exploration: 1.2415623485717155, score: 18
# Scores: (min: 12, avg: 21.7, max: 39)
#
# Run: 11, exploration: 1.2024420545907453, score: 33
# Scores: (min: 12, avg: 22.727272727272727, max: 39)
#
# Run: 12, exploration: 1.1610642282907617, score: 36
# Scores: (min: 12, avg: 23.833333333333332, max: 39)
#
# Run: 13, exploration: 1.1472078329300177, score: 13
# Scores: (min: 12, avg: 23, max: 39)
#
# Run: 14, exploration: 1.1144004073694351, score: 30
# Scores: (min: 12, avg: 23.5, max: 39)
#
# Run: 15, exploration: 1.1033064178197673, score: 11
# Scores: (min: 11, avg: 22.666666666666668, max: 39)
#
# Run: 16, exploration: 1.08796012835298, score: 15
# Scores: (min: 11, avg: 22.1875, max: 39)
#
# Run: 17, exploration: 1.0400637257301508, score: 46
# Scores: (min: 11, avg: 23.58823529411765, max: 46)
#
# Run: 18, exploration: 1.0184394237911392, score: 22
# Scores: (min: 11, avg: 23.5, max: 46)
#
# Run: 19, exploration: 0.9972647197207785, score: 22
# Scores: (min: 11, avg: 23.42105263157895, max: 46)
#
# Run: 20, exploration: 0.9843777805065995, score: 14
# Scores: (min: 11, avg: 22.95, max: 46)
#
# Run: 21, exploration: 0.9639112630989424, score: 22
# Scores: (min: 11, avg: 22.904761904761905, max: 46)
#
# Run: 22, exploration: 0.9335394561354189, score: 33
# Scores: (min: 11, avg: 23.363636363636363, max: 46)
#
# Run: 23, exploration: 0.9150449797829574, score: 21
# Scores: (min: 11, avg: 23.26086956521739, max: 46)
#
# Run: 24, exploration: 0.8969169000014212, score: 21
# Scores: (min: 11, avg: 23.166666666666668, max: 46)
#
# Run: 25, exploration: 0.8879879848200058, score: 11
# Scores: (min: 11, avg: 22.68, max: 46)
#
# Run: 26, exploration: 0.8488951642866274, score: 46
# Scores: (min: 11, avg: 23.576923076923077, max: 46)
#
# Run: 27, exploration: 0.8270975864514785, score: 27
# Scores: (min: 11, avg: 23.703703703703702, max: 46)
#
# Run: 28, exploration: 0.8155931858842748, score: 15
# Scores: (min: 11, avg: 23.392857142857142, max: 46)
#
# Run: 29, exploration: 0.80023559462924, score: 20
# Scores: (min: 11, avg: 23.275862068965516, max: 46)
#
# Run: 30, exploration: 0.7883157224299643, score: 16
# Scores: (min: 11, avg: 23.033333333333335, max: 46)
#
# Run: 31, exploration: 0.7657717607871957, score: 30
# Scores: (min: 11, avg: 23.258064516129032, max: 46)
#
# Run: 32, exploration: 0.7566328725026251, score: 13
# Scores: (min: 11, avg: 22.9375, max: 46)
#
# Run: 33, exploration: 0.7423855018929512, score: 20
# Scores: (min: 11, avg: 22.848484848484848, max: 46)
#
# Run: 34, exploration: 0.733525710355444, score: 13
# Scores: (min: 11, avg: 22.558823529411764, max: 46)
#
# Run: 35, exploration: 0.7111242285479629, score: 32
# Scores: (min: 11, avg: 22.82857142857143, max: 46)
#
# Run: 36, exploration: 0.6949470325933219, score: 24
# Scores: (min: 11, avg: 22.86111111111111, max: 46)
#
# Run: 37, exploration: 0.6643526550907015, score: 46
# Scores: (min: 11, avg: 23.486486486486488, max: 46)
#
# Run: 38, exploration: 0.6505398837650025, score: 22
# Scores: (min: 11, avg: 23.44736842105263, max: 46)
#
# Run: 39, exploration: 0.6395687383423362, score: 18
# Scores: (min: 11, avg: 23.307692307692307, max: 46)
#
# Run: 40, exploration: 0.6231461576263055, score: 27
# Scores: (min: 11, avg: 23.4, max: 46)
#
# Run: 41, exploration: 0.6157093945970029, score: 13
# Scores: (min: 11, avg: 23.146341463414632, max: 46)
#
# Run: 42, exploration: 0.6071452691244279, score: 15
# Scores: (min: 11, avg: 22.952380952380953, max: 46)
#
# Run: 43, exploration: 0.5975034633517385, score: 17
# Scores: (min: 11, avg: 22.813953488372093, max: 46)
#
# Run: 44, exploration: 0.5757891691154556, score: 38
# Scores: (min: 11, avg: 23.15909090909091, max: 46)
#
# Run: 45, exploration: 0.5677803085501851, score: 15
# Scores: (min: 11, avg: 22.977777777777778, max: 46)
#
# Run: 46, exploration: 0.5593229632876076, score: 16
# Scores: (min: 11, avg: 22.82608695652174, max: 46)
#
# Run: 47, exploration: 0.5304366527684574, score: 54
# Scores: (min: 11, avg: 23.48936170212766, max: 54)
#
# Run: 48, exploration: 0.5204485490901825, score: 20
# Scores: (min: 11, avg: 23.416666666666668, max: 54)
#
# Run: 49, exploration: 0.5152674214393269, score: 11
# Scores: (min: 11, avg: 23.163265306122447, max: 54)
#
# Run: 50, exploration: 0.5055649538581135, score: 20
# Scores: (min: 11, avg: 23.1, max: 54)
#
# Run: 51, exploration: 0.49953143072433576, score: 13
# Scores: (min: 11, avg: 22.901960784313726, max: 54)
#
# Run: 52, exploration: 0.48670466989401895, score: 27
# Scores: (min: 11, avg: 22.98076923076923, max: 54)
#
# Run: 53, exploration: 0.47945498304821554, score: 16
# Scores: (min: 11, avg: 22.849056603773583, max: 54)
#
# Run: 54, exploration: 0.4756327411074111, score: 9
# Scores: (min: 9, avg: 22.59259259259259, max: 54)
#
# Run: 55, exploration: 0.459725233617431, score: 35
# Scores: (min: 9, avg: 22.818181818181817, max: 54)
#
# Run: 56, exploration: 0.4492670536103906, score: 24
# Scores: (min: 9, avg: 22.839285714285715, max: 54)
#
# Run: 57, exploration: 0.43293992315655244, score: 38
# Scores: (min: 9, avg: 23.105263157894736, max: 54)
#
# Run: 58, exploration: 0.41346627754366383, score: 47
# Scores: (min: 9, avg: 23.517241379310345, max: 54)
#
# Run: 59, exploration: 0.40325271472435087, score: 26
# Scores: (min: 9, avg: 23.559322033898304, max: 54)
#
# Run: 60, exploration: 0.3944736883075402, score: 23
# Scores: (min: 9, avg: 23.55, max: 54)
#
# Run: 61, exploration: 0.3652251146995767, score: 78
# Scores: (min: 9, avg: 24.442622950819672, max: 78)
#
# Run: 62, exploration: 0.3615892549323339, score: 11
# Scores: (min: 9, avg: 24.225806451612904, max: 78)
#
# Run: 63, exploration: 0.34360178865281993, score: 52
# Scores: (min: 9, avg: 24.666666666666668, max: 78)
#
# Run: 64, exploration: 0.33645785252583216, score: 22
# Scores: (min: 9, avg: 24.625, max: 78)
#
# Run: 65, exploration: 0.3284750490027614, score: 25
# Scores: (min: 9, avg: 24.630769230769232, max: 78)
#
# Run: 66, exploration: 0.3127600754091316, score: 50
# Scores: (min: 9, avg: 25.015151515151516, max: 78)
#
# Run: 67, exploration: 0.30902752801655126, score: 13
# Scores: (min: 9, avg: 24.83582089552239, max: 78)
#
# Run: 68, exploration: 0.3010924473628582, score: 27
# Scores: (min: 9, avg: 24.86764705882353, max: 78)
#
# Run: 69, exploration: 0.2936547751932421, score: 26
# Scores: (min: 9, avg: 24.884057971014492, max: 78)
#
# Run: 70, exploration: 0.28072690497242414, score: 46
# Scores: (min: 9, avg: 25.185714285714287, max: 78)
#
# Run: 71, exploration: 0.2740663746587126, score: 25
# Scores: (min: 9, avg: 25.183098591549296, max: 78)
#
# Run: 72, exploration: 0.26890571437904853, score: 20
# Scores: (min: 9, avg: 25.11111111111111, max: 78)
#
# Run: 73, exploration: 0.25939261501369826, score: 37
# Scores: (min: 9, avg: 25.273972602739725, max: 78)
#
# Run: 74, exploration: 0.25655352012807164, score: 12
# Scores: (min: 9, avg: 25.094594594594593, max: 78)
#
# Run: 75, exploration: 0.24698269801178727, score: 39
# Scores: (min: 9, avg: 25.28, max: 78)
#
# Run: 76, exploration: 0.24427943171129335, score: 12
# Scores: (min: 9, avg: 25.105263157894736, max: 78)
#
# Run: 77, exploration: 0.23872237701418217, score: 24
# Scores: (min: 9, avg: 25.09090909090909, max: 78)
#
# Run: 78, exploration: 0.23446170468259991, score: 19
# Scores: (min: 9, avg: 25.012820512820515, max: 78)
#
# Run: 79, exploration: 0.23120049172233662, score: 15
# Scores: (min: 9, avg: 24.88607594936709, max: 78)
#
# Run: 80, exploration: 0.2140579425466207, score: 78
# Scores: (min: 9, avg: 25.55, max: 78)
#
# Run: 81, exploration: 0.20939778710630458, score: 23
# Scores: (min: 9, avg: 25.51851851851852, max: 78)
#
# Run: 82, exploration: 0.20118315604573692, score: 41
# Scores: (min: 9, avg: 25.70731707317073, max: 78)
# Run: 83, exploration: 0.18275887941697883, score: 97
# Scores: (min: 9, avg: 26.566265060240966, max: 97)
#
# Run: 84, exploration: 0.18075855338677094, score: 12
# Scores: (min: 9, avg: 26.392857142857142, max: 97)
#
# Run: 85, exploration: 0.1782443170521789, score: 15
# Scores: (min: 9, avg: 26.258823529411764, max: 97)
#
# Run: 86, exploration: 0.167021518132341, score: 66
# Scores: (min: 9, avg: 26.72093023255814, max: 97)
#
# Run: 87, exploration: 0.1650282466727592, score: 13
# Scores: (min: 9, avg: 26.563218390804597, max: 97)
#
# Run: 88, exploration: 0.16240750599940948, score: 17
# Scores: (min: 9, avg: 26.454545454545453, max: 97)
#
# Run: 89, exploration: 0.15919002894535694, score: 21
# Scores: (min: 9, avg: 26.39325842696629, max: 97)
#
# Run: 90, exploration: 0.1520296585498867, score: 47
# Scores: (min: 9, avg: 26.622222222222224, max: 97)
#
# Run: 91, exploration: 0.14665129293350307, score: 37
# Scores: (min: 9, avg: 26.736263736263737, max: 97)
#
# Run: 92, exploration: 0.14360221838192763, score: 22
# Scores: (min: 9, avg: 26.684782608695652, max: 97)
#
# Run: 93, exploration: 0.14245741346530683, score: 9
# Scores: (min: 9, avg: 26.49462365591398, max: 97)
#
# Run: 94, exploration: 0.1410392328492502, score: 11
# Scores: (min: 9, avg: 26.329787234042552, max: 97)
#
# Run: 95, exploration: 0.13659523834646867, score: 33
# Scores: (min: 9, avg: 26.4, max: 97)
#
# Run: 96, exploration: 0.12309667884061044, score: 105
# Scores: (min: 9, avg: 27.21875, max: 105)
#
# Run: 97, exploration: 0.11874187760457328, score: 37
# Scores: (min: 9, avg: 27.31958762886598, max: 105)
#
# Run: 98, exploration: 0.11732478597271054, score: 13
# Scores: (min: 9, avg: 27.1734693877551, max: 105)
#
# Run: 99, exploration: 0.11500044877895929, score: 21
# Scores: (min: 9, avg: 27.11111111111111, max: 105)
#
# Run: 100, exploration: 0.11294794228015316, score: 19
# Scores: (min: 9, avg: 27.03, max: 105)
#
# Run: 101, exploration: 0.10594234207443032, score: 65
# Scores: (min: 9, avg: 27.5, max: 105)
#
# Run: 102, exploration: 0.1, score: 94
# Scores: (min: 9, avg: 28.3, max: 105)
#
# Run: 103, exploration: 0.1, score: 27
# Scores: (min: 9, avg: 28.41, max: 105)
#
# Run: 104, exploration: 0.1, score: 115
# Scores: (min: 9, avg: 29.21, max: 115)
#
# Run: 105, exploration: 0.1, score: 38
# Scores: (min: 9, avg: 29.2, max: 115)
#
# Run: 106, exploration: 0.1, score: 13
# Scores: (min: 9, avg: 29.04, max: 115)
#
# Run: 107, exploration: 0.1, score: 10
# Scores: (min: 9, avg: 29.02, max: 115)
#
# Run: 108, exploration: 0.1, score: 10
# Scores: (min: 9, avg: 28.99, max: 115)
#
# Run: 109, exploration: 0.1, score: 54
# Scores: (min: 9, avg: 29.3, max: 115)
#
# Run: 110, exploration: 0.1, score: 26
# Scores: (min: 9, avg: 29.38, max: 115)
#
# Run: 111, exploration: 0.1, score: 63
# Scores: (min: 9, avg: 29.68, max: 115)
#
# Run: 112, exploration: 0.1, score: 24
# Scores: (min: 9, avg: 29.56, max: 115)
#
# Run: 113, exploration: 0.1, score: 16
# Scores: (min: 9, avg: 29.59, max: 115)
#
# Run: 114, exploration: 0.1, score: 15
# Scores: (min: 9, avg: 29.44, max: 115)
#
# Run: 115, exploration: 0.1, score: 19
# Scores: (min: 9, avg: 29.52, max: 115)
#
# Run: 116, exploration: 0.1, score: 21
# Scores: (min: 9, avg: 29.58, max: 115)
#
# Run: 117, exploration: 0.1, score: 52
# Scores: (min: 9, avg: 29.64, max: 115)
#
# Run: 118, exploration: 0.1, score: 54
# Scores: (min: 9, avg: 29.96, max: 115)
#
# Run: 119, exploration: 0.1, score: 27
# Scores: (min: 9, avg: 30.01, max: 115)
#
# Run: 120, exploration: 0.1, score: 35
# Scores: (min: 9, avg: 30.22, max: 115)
#
# Run: 121, exploration: 0.1, score: 18
# Scores: (min: 9, avg: 30.18, max: 115)
#
# Run: 122, exploration: 0.1, score: 59
# Scores: (min: 9, avg: 30.44, max: 115)
#
# Run: 123, exploration: 0.1, score: 31
# Scores: (min: 9, avg: 30.54, max: 115)
#
# Run: 124, exploration: 0.1, score: 56
# Scores: (min: 9, avg: 30.89, max: 115)
#
# Run: 125, exploration: 0.1, score: 39
# Scores: (min: 9, avg: 31.17, max: 115)
#
# Run: 126, exploration: 0.1, score: 25
# Scores: (min: 9, avg: 30.96, max: 115)
#
# Run: 127, exploration: 0.1, score: 19
# Scores: (min: 9, avg: 30.88, max: 115)
#
# Run: 128, exploration: 0.1, score: 14
# Scores: (min: 9, avg: 30.87, max: 115)
#
# Run: 129, exploration: 0.1, score: 31
# Scores: (min: 9, avg: 30.98, max: 115)
#
# Run: 130, exploration: 0.1, score: 51
# Scores: (min: 9, avg: 31.33, max: 115)
#
# Run: 131, exploration: 0.1, score: 16
# Scores: (min: 9, avg: 31.19, max: 115)
#
# Run: 132, exploration: 0.1, score: 35
# Scores: (min: 9, avg: 31.41, max: 115)
#
# Run: 133, exploration: 0.1, score: 86
# Scores: (min: 9, avg: 32.07, max: 115)
#
# Run: 134, exploration: 0.1, score: 16
# Scores: (min: 9, avg: 32.1, max: 115)
#
# Run: 135, exploration: 0.1, score: 51
# Scores: (min: 9, avg: 32.29, max: 115)
#
# Run: 136, exploration: 0.1, score: 35
# Scores: (min: 9, avg: 32.4, max: 115)
#
# Run: 137, exploration: 0.1, score: 15
# Scores: (min: 9, avg: 32.09, max: 115)
#
# Run: 138, exploration: 0.1, score: 16
# Scores: (min: 9, avg: 32.03, max: 115)
#
# Run: 139, exploration: 0.1, score: 15
# Scores: (min: 9, avg: 32, max: 115)
#
# Run: 140, exploration: 0.1, score: 13
# Scores: (min: 9, avg: 31.86, max: 115)
#
# Run: 141, exploration: 0.1, score: 67
# Scores: (min: 9, avg: 32.4, max: 115)
#
# Run: 142, exploration: 0.1, score: 63
# Scores: (min: 9, avg: 32.88, max: 115)
#
# Run: 143, exploration: 0.1, score: 10
# Scores: (min: 9, avg: 32.81, max: 115)
#
# Run: 144, exploration: 0.1, score: 33
# Scores: (min: 9, avg: 32.76, max: 115)
#
# Run: 145, exploration: 0.1, score: 20
# Scores: (min: 9, avg: 32.81, max: 115)
#
# Run: 146, exploration: 0.1, score: 25
# Scores: (min: 9, avg: 32.9, max: 115)
#
# Run: 147, exploration: 0.1, score: 111
# Scores: (min: 9, avg: 33.47, max: 115)
#
# Run: 148, exploration: 0.1, score: 16
# Scores: (min: 9, avg: 33.43, max: 115)
#
# Run: 149, exploration: 0.1, score: 36
# Scores: (min: 9, avg: 33.68, max: 115)
#
# Run: 150, exploration: 0.1, score: 87
# Scores: (min: 9, avg: 34.35, max: 115)
#
# Run: 151, exploration: 0.1, score: 11
# Scores: (min: 9, avg: 34.33, max: 115)
#
# Run: 152, exploration: 0.1, score: 57
# Scores: (min: 9, avg: 34.63, max: 115)
#
# Run: 153, exploration: 0.1, score: 102
# Scores: (min: 9, avg: 35.49, max: 115)
#
# Run: 154, exploration: 0.1, score: 13
# Scores: (min: 9, avg: 35.53, max: 115)
#
# Run: 155, exploration: 0.1, score: 45
# Scores: (min: 9, avg: 35.63, max: 115)
#
# Run: 156, exploration: 0.1, score: 9
# Scores: (min: 9, avg: 35.48, max: 115)

# %%
EXPLORATION_MAX = 0.5
EXPLORATION_MIN = 0.001
EXPLORATION_DECAY = 0.99
cartpole()

# %% [markdown]
# The goal of the agent in the Cartpole Problem is to keep the inverted pendulum, the cartpole, balanced by applying appropriate forces to a pivot point (Surma, 2019). The values which contribute to the state of the cartpole are cart position, cart velocity, pole angle, and pole velocity. The possible actions that can be performed are moving the cart to the left, applying a force of -1, or moving the cart to the right, applying a force of +1. The reinforcement algorithm used in this instance is Deep Q-Learning (DQN).
# In the Cartpole Problem, the agent is awarded a reward of +1 point for each timestep the pole remains upright. The run ends when the pole is more 15 degrees from vertical or the cart moves more than 2.4 units from the center (Surma, 2019). This reward structure allows for states to be captured in memory. This allows the agent to refer to this memory to choose the best possible move from previous experiences. Essentially, the reward structure incentivizes moves that keep the pole upright and allows the agent to remember moves and sequences of moves that generated the best score, therefore, keeping the pole upright the longest amount of time. In this instance the discount factor promotes the importance of future rewards. A low discount factor will make the agent short-sighted by only considering current rewards. A higher discount factor will cause the agent to pursue long-term rewards (Shaw et al., 2021).
# The Cartpole Problem utilizes 3 dense layers. The first layer has 4 input receptors with 24 output transmitters. This layer uses the ReLU activation method. The first layer takes in the current values to determine the state. The next layer has 24 input receptors with 24 output transmitters. This layer uses the ReLU activation method. The second layer takes in data from the first layer and processes the data by referring to memory. The final layer has 24 input receptors with 2 output transmitters. This layer uses a linear activation method. The final layer processes memories and determines which move should be used, pushing the cart right or left. This structure allows for the state to be taken in as the input and Q-values to be generateed as output for all possible actions. This ends with the decision of which action to take. The generation of Q-values allows the Q algorithm to be more efficient. Lower learning rates take more time for completion but makes the agent more accurate. Higher learning rates can result in an agent that is very inaccurate.
#
# Works Cited:
# Surma, G. (2019, November 10). Cartpole - introduction to reinforcement learning (DQN - deep Q-learning). Medium.
#     https://gsurma.medium.com/cartpole-introduction-to-reinforcement-learning-ed0eb5b58288
# Shaw, R. N., Ghosh, A., Balas, V. E., &amp; Bianchini, M. (Eds.). (2021). Artificial Intelligence for Future Generation             Robotics. Elsevier.

# %% [markdown]
# Note: If the code is running properly, you should begin to see output appearing above this code block. It will take several minutes, so it is recommended that you let this code run in the background while completing other work. When the code has finished, it will print output saying, "Solved in _ runs, _ total runs."
#
# You may see an error about not having an exit command. This error does not affect the program's functionality and results from the steps taken to convert the code from Python 2.x to Python 3. Please disregard this error.
